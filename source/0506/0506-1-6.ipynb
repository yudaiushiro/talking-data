# %% [markdown]
# train全データ特徴量抽出

# %%
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import gc
from contextlib import contextmanager
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ['ip_count', 'ip_app_nextClick', 'cumcount_ip_by_os', 'ip_app_os_count', 'os_device_count', 'ip_by_app_countuniq', 'ip_by_device_countuniq', 'ip_app_by_os_countuniq', 'ip_os_nextClick', 'ip_app_count', 'app_by_channel_countuniq', 'channel', 'ip_device_count', 'ip_nextClick', 'ip_channel_nextClick', 'os_app_channel_count', 'ip_hour_count', 'ip_device_os_by_app_countuniq', 'ip_app_device_os_channel_nextClick', 'ip_os_device_nextClick', 'app_channel_count', 'ip_os_device_app_nextClick', 'ip_by_channel_countuniq', 'ip_by_hour_countuniq', 'device', 'app', 'os', 'cumcount_ip_dev_os_by_app', 'hour']

# %%
@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f'[{name}] done in {time.time() - t0:.0f} s')
    
def do_next_Click(df,agg_suffix='nextClick', agg_type='float32'):
    with timer("Adding next click times"):
    
        print(f">> \nExtracting {agg_suffix} time calculation features...\n")

        GROUP_BY_NEXT_CLICKS = [

        # V1
        {'groupby': ['ip']},
        {'groupby': ['ip', 'app']},
        {'groupby': ['ip', 'channel']},
        {'groupby': ['ip', 'os']},

        # V3
        {'groupby': ['ip', 'app', 'device', 'os', 'channel']},
        {'groupby': ['ip', 'os', 'device']},
        {'groupby': ['ip', 'os', 'device', 'app']},
    #     {'groupby': ['device']},
    #     {'groupby': ['device', 'channel']},     
#         {'groupby': ['app', 'device', 'channel']},
#         {'groupby': ['device', 'hour']}
        ]

        # Calculate the time to next click for each group
        for spec in GROUP_BY_NEXT_CLICKS:

           # Name of new feature
            new_feature = '{}_{}'.format('_'.join(spec['groupby']),agg_suffix)    

            # Unique list of features to select
            all_features = spec['groupby'] + ['click_time']

            # Run calculation
            print(f">> Grouping by {spec['groupby']}, and saving time to {agg_suffix} in: {new_feature}")
            df[new_feature] = (df[all_features].groupby(spec[
                'groupby']).click_time.shift(-1) - df.click_time).dt.seconds.astype(agg_type)

#             predictors.append(new_feature)
            gc.collect()
        return (df)
    
def df_add_counts(df, cols):
    arr_slice = df[cols].values
    unq, unqtags, counts = np.unique(np.ravel_multi_index(arr_slice.T, arr_slice.max(axis=0) + 1),
                                     return_inverse=True, return_counts=True)
    df["_".join(cols)+'_count'] = counts[unqtags]
    gc.collect()
    
def make_count_features(df):
    with timer("add count features"):
        df['click_time']= pd.to_datetime(df['click_time'])
        dt= df['click_time'].dt
#         df['day'] = dt.day.astype('uint8')
        df['hour'] = dt.hour.astype('uint8')
#         df['minute'] = dt.minute.astype('uint8')
#         df['second'] = dt.second.astype('uint8')#secondを追加

        del(dt)
    
#         df_add_counts(df, ['ip','channel','hour'])
#         df_add_counts(df, ['ip','day'])
#         df_add_counts(df, ['ip','day','hour','channel'])

        
        df_add_counts(df, ['ip'])
# #         df_add_counts(df, ['ip','day','hour','minute'])
        df_add_counts(df, ['os','device'])
        df_add_counts(df, ['os','app','channel'])
        
        df_add_counts(df, ['ip', 'hour'])
        df_add_counts(df, ['ip', 'app'])
        df_add_counts(df, ['ip', 'app', 'os'])
        df_add_counts(df, ['ip', 'device'])
        df_add_counts(df, ['app', 'channel'])

def do_countuniq( df, group_cols, counted, agg_type='uint32', show_max=False, show_agg=True ):
    with timer("add countuniq feature"):
        agg_name= '{}_by_{}_countuniq'.format(('_'.join(group_cols)),(counted))  
        if show_agg:
            print( "\nCounting unqiue ", counted, " by ", group_cols ,  '... and saved in', agg_name )
        gp = df[group_cols+[counted]].groupby(group_cols)[counted].nunique().reset_index().rename(columns={counted:agg_name})
        df = df.merge(gp, on=group_cols, how='left')
        del gp
        if show_max:
            print( agg_name + " max value = ", df[agg_name].max() )
        df[agg_name] = df[agg_name].astype(agg_type)
    #     predictors.append(agg_name)
    #     print('predictors',predictors)
        gc.collect()
        return( df )

def make_countuniq_features(df):
    with timer("add countuniq features"):
        df = do_countuniq( df, ['ip'], 'channel' ); gc.collect()
        df = do_countuniq( df, ['ip', 'device', 'os'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip'], 'hour' ); gc.collect()
        df = do_countuniq( df, ['ip'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip', 'app'], 'os'); gc.collect()
        df = do_countuniq( df, ['ip'], 'device'); gc.collect()
        df = do_countuniq( df, ['app'], 'channel'); gc.collect()
        return(df)

def do_cumcount( df, group_cols, counted, agg_name, agg_type='uint16', show_max=False, show_agg=True ):
    with timer("add countuniq feature"):
        if show_agg:
            print( "Cumulative count by ", group_cols , '...' )
        gp = df[group_cols+[counted]].groupby(group_cols)[counted].cumcount()
        df[agg_name]=gp.values
        del gp
        if show_max:
            print( agg_name + " max value = ", df[agg_name].max() )
        df[agg_name] = df[agg_name].astype(agg_type)
        gc.collect()
        return( df )

# def make_next_click_feature(df):
#     with timer("Adding next click times"):
#         D= 2**26
#         df['category'] = (df['ip'].astype(str) + "_" + df['app'].astype(str) + "_" + df['device'].astype(str) \
#                          + "_" + df['os'].astype(str)).apply(hash) % D
#         click_buffer= np.full(D, 3000000000, dtype=np.uint32)
#         df['epochtime']= df['click_time'].astype(np.int64) // 10 ** 9
#         next_clicks= []
#         for category, time in zip(reversed(df['category'].values), reversed(df['epochtime'].values)):
#             next_clicks.append(click_buffer[category]-time)
#             click_buffer[category]= time
#         del(click_buffer)
#         df['next_click']= list(reversed(next_clicks))
#         gc.collect()
        
path = '~/talkingdata/input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

columns = ['ip','app','device','os', 'channel', 'click_time', 'is_attributed']

# %%
with timer("load training data"):
    train_df = pd.read_csv(path+"train.csv", usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)

with timer("load test data"):
    testsup_df = pd.read_csv(path+"test_supplement.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load training data] done in 103 s
# [load test data] done in 34 s

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184903890 entries, 0 to 184903889
# Data columns (total 7 columns):
# ip               uint32
# app              uint16
# device           uint16
# os               uint16
# channel          uint16
# click_time       object
# is_attributed    uint8
# dtypes: object(1), uint16(4), uint32(1), uint8(1)
# memory usage: 3.6+ GB

# %%
num_train = train_df.shape[0]

y = train_df.is_attributed.values
gc.collect()

# sub = pd.DataFrame()
# sub['click_id'] = test_df.click_id.values

common_column = ['ip','app','device','os','channel','click_time']
concat_df = pd.concat([train_df[common_column],testsup_df[common_column]])

del train_df, testsup_df
gc.collect()
# Out:
# 118

# %%
make_count_features(concat_df)
# Out:
# [add count features] done in 993 s

# %%
concat_df = make_countuniq_features(concat_df)

gc.collect()
# Out:
# Counting unqiue  channel  by  ['ip'] ... and saved in ip_by_channel_countuniq
#
# Counting unqiue  app  by  ['ip', 'device', 'os'] ... and saved in ip_device_os_by_app_countuniq
#
# Counting unqiue  hour  by  ['ip'] ... and saved in ip_by_hour_countuniq
#
# Counting unqiue  app  by  ['ip'] ... and saved in ip_by_app_countuniq
#
# Counting unqiue  os  by  ['ip', 'app'] ... and saved in ip_app_by_os_countuniq
#
# Counting unqiue  device  by  ['ip'] ... and saved in ip_by_device_countuniq
#
# Counting unqiue  channel  by  ['app'] ... and saved in app_by_channel_countuniq
# [add countuniq features] done in 2264 s
# 41

# %%
concat_df = do_cumcount(concat_df, ['ip', 'device', 'os'], 'app', 'cumcount_ip_dev_os_by_app', show_max=True )
# concat_df = do_cumcount(concat_df, ['ip'], 'app', 'cumcount_ip_by_app', show_max=True )
concat_df = do_cumcount(concat_df, ['ip'], 'os', 'cumcount_ip_by_os', show_max=True )
gc.collect()
# Out:
# Cumulative count by  ['ip', 'device', 'os'] ...
# cumcount_ip_dev_os_by_app max value =  342409
# [add countuniq feature] done in 141 s
# Cumulative count by  ['ip'] ...
# cumcount_ip_by_os max value =  1742880
# [add countuniq feature] done in 70 s
# 0

# %%
concat_df.head(100000)
# Out:
#            ip  app  device  os  channel          click_time  hour  ip_count  \
# 0       83230    3       1  13      379 2017-11-06 14:32:21    14     32794
# 1       17357    3       1  19      379 2017-11-06 14:33:34    14     30826
# 2       35810    3       1  13      379 2017-11-06 14:34:12    14     13162
# 3       45745   14       1  13      478 2017-11-06 14:34:52    14    220500
# 4      161007    3       1  13      379 2017-11-06 14:35:08    14      1171
# 5       18787    3       1  16      379 2017-11-06 14:36:26    14      4639
# 6      103022    3       1  23      379 2017-11-06 14:37:44    14      7175
# 7      114221    3       1  19      379 2017-11-06 14:37:59    14      3301
# 8      165970    3       1  13      379 2017-11-06 14:38:10    14      2014
# 9       74544   64       1  22      459 2017-11-06 14:38:23    14      4442
# 10     172522    3       1  25      379 2017-11-06 14:38:27    14      9494
# 11     105861    3       1  13      379 2017-11-06 14:38:51    14     13633
# 12     210962    3       1  19      379 2017-11-06 14:39:29    14      8688
# 13     124979    3       1  18      379 2017-11-06 14:40:16    14      1098
# 14      38816    3       1  18      379 2017-11-06 14:40:39    14      5508
# 15      80447    3       1  19      379 2017-11-06 14:40:51    14      6411
# 16     134575    3       1  13      379 2017-11-06 14:43:10    14      3267
# 17      57576    3       1  19      379 2017-11-06 14:43:14    14       504
# 18       7755    3       1  13      379 2017-11-06 14:43:25    14      1106
# 19      91749    3       1  19      379 2017-11-06 14:43:51    14      7722
# 20      50694    3       1  18      379 2017-11-06 14:44:02    14      1939
# 21     111385    3       1  18      379 2017-11-06 14:44:15    14      3243
# 22     125222   14       1   3      478 2017-11-06 14:44:51    14    210814
# 23     191759    3       1  13      379 2017-11-06 14:44:51    14     25290
# 24      53418    3       1  17      379 2017-11-06 14:44:52    14      3395
# 25     183168    3       1  19      379 2017-11-06 14:47:49    14        90
# 26      47902    3       1  17      379 2017-11-06 14:48:07    14      6712
# 27     209663    3       1  13      379 2017-11-06 14:48:55    14    173423
# 28     129614    3       1  20      379 2017-11-06 14:49:36    14      2201
# 29     208347    3       1  19      379 2017-11-06 14:49:38    14      2753
# ...       ...  ...     ...  ..      ...                 ...   ...       ...
# 99970   15660   12       1  19      259 2017-11-06 16:01:48    16      5243
# 99971  192610    2       1   8      237 2017-11-06 16:01:48    16        83
# 99972  121472   36       1  14      110 2017-11-06 16:01:48    16    104750
# 99973   49025    9       1  18      442 2017-11-06 16:01:48    16     15515
# 99974   93715   14       1   8      467 2017-11-06 16:01:48    16     24609
# 99975   81541    9       1   9      134 2017-11-06 16:01:48    16     14617
# 99976  162789    1       1  17      153 2017-11-06 16:01:48    16      3390
# 99977  128108    9       1  17      134 2017-11-06 16:01:48    16      2362
# 99978   72867    3       1  27      137 2017-11-06 16:01:48    16      8297
# 99979   85065   12       1  19      178 2017-11-06 16:01:48    16     38854
# 99980   41640   15       1  10      140 2017-11-06 16:01:48    16      4509
# 99981    3994    9       1  19      134 2017-11-06 16:01:48    16    167898
# 99982   28034    8       1  17      145 2017-11-06 16:01:48    16      5886
# 99983   88176    9       1   8      134 2017-11-06 16:01:48    16      9239
# 99984   17248   13       1  13      477 2017-11-06 16:01:48    16      1501
# 99985   73516   12       1  22      326 2017-11-06 16:01:48    16    998301
# 99986  109567   13       1  19      400 2017-11-06 16:01:48    16     19829
# 99987   86840    8       1  15      145 2017-11-06 16:01:48    16     20130
# 99988   93587    9       1  25      134 2017-11-06 16:01:48    16    227293
# 99989   74889   17       1  19      280 2017-11-06 16:01:48    16     13401
# 99990  133901    8       1  13      145 2017-11-06 16:01:48    16       938
# 99991   98293    3       1  19      409 2017-11-06 16:01:48    16     18224
# 99992  160682    2       1  13      122 2017-11-06 16:01:48    16      4746
# 99993   86669    2       1   1      212 2017-11-06 16:01:48    16      6909
# 99994   44545    2       1  13      236 2017-11-06 16:01:48    16     21431
# 99995  137399   15       1  19      140 2017-11-06 16:01:48    16      1405
# 99996   81341    1       1  13      134 2017-11-06 16:01:48    16     13610
# 99997  153416    8       1  18      145 2017-11-06 16:01:48    16        97
# 99998   73487   64       1  13      459 2017-11-06 16:01:48    16    991252
# 99999   39889   12       1  20      245 2017-11-06 16:01:48    16     11752
#
#        os_device_count  os_app_channel_count        ...          \
# 0             49858614                282708        ...
# 1             56240944                337657        ...
# 2             49858614                282708        ...
# 3             49858614                  5659        ...
# 4             49858614                282708        ...
# 5              3846516                 20906        ...
# 6              2476947                  8565        ...
# 7             56240944                337657        ...
# 8             49858614                282708        ...
# 9              9563728                 63180        ...
# 10             5179756                 29111        ...
# 11            49858614                282708        ...
# 12            56240944                337657        ...
# 13            11290342                 59290        ...
# 14            11290342                 59290        ...
# 15            56240944                337657        ...
# 16            49858614                282708        ...
# 17            56240944                337657        ...
# 18            49858614                282708        ...
# 19            56240944                337657        ...
# 20            11290342                 59290        ...
# 21            11290342                 59290        ...
# 22             3673622                   273        ...
# 23            49858614                282708        ...
# 24            11929590                 64331        ...
# 25            56240944                337657        ...
# 26            11929590                 64331        ...
# 27            49858614                282708        ...
# 28             4990115                 26371        ...
# 29            56240944                337657        ...
# ...                ...                   ...        ...
# 99970         56240944                723220        ...
# 99971          6683440                 98782        ...
# 99972          3187902                  2909        ...
# 99973         11290342                108360        ...
# 99974          6683440                 10670        ...
# 99975          4318346                 84122        ...
# 99976         11929590                 65248        ...
# 99977         11929590                157915        ...
# 99978          2169288                 27303        ...
# 99979         56240944               1605539        ...
# 99980          6575449                 33356        ...
# 99981         56240944                622457        ...
# 99982         11929590                254865        ...
# 99983          6683440                 79124        ...
# 99984         49858614                848970        ...
# 99985          9563728                 29767        ...
# 99986         56240944                222368        ...
# 99987          5586078                109538        ...
# 99988          5179756                 60808        ...
# 99989         56240944                119297        ...
# 99990         49858614               1056860        ...
# 99991         56240944                437276        ...
# 99992         49858614                468081        ...
# 99993          2835136                 14773        ...
# 99994         49858614                403755        ...
# 99995         56240944                279805        ...
# 99996         49858614                338813        ...
# 99997         11290342                224515        ...
# 99998         49858614                345245        ...
# 99999          4990115                 69037        ...
#
#        app_channel_count  ip_by_channel_countuniq  \
# 0                1314929                      141
# 1                1314929                      137
# 2                1314929                      139
# 3                  24090                      152
# 4                1314929                       94
# 5                1314929                      111
# 6                1314929                      109
# 7                1314929                       94
# 8                1314929                       93
# 9                1895374                      106
# 10               1314929                      111
# 11               1314929                      114
# 12               1314929                      131
# 13               1314929                       89
# 14               1314929                      113
# 15               1314929                      109
# 16               1314929                      104
# 17               1314929                       74
# 18               1314929                       91
# 19               1314929                      111
# 20               1314929                       96
# 21               1314929                      107
# 22                 24090                      149
# 23               1314929                      134
# 24               1314929                      102
# 25               1314929                       43
# 26               1314929                      116
# 27               1314929                      137
# 28               1314929                      102
# 29               1314929                       92
# ...                  ...                      ...
# 99970            3595493                      113
# 99971            3313464                       34
# 99972              81422                      144
# 99973            2145481                      126
# 99974             373162                      141
# 99975            2613935                      118
# 99976            1222050                      111
# 99977            2613935                      102
# 99978            2566636                      119
# 99979            6226379                      138
# 99980            1204309                      113
# 99981            2613935                      151
# 99982            4455215                      117
# 99983            2613935                      110
# 99984            3876081                       94
# 99985             587734                      163
# 99986             946587                      122
# 99987            4455215                      136
# 99988            2613935                      149
# 99989             569968                      125
# 99990            4455215                       82
# 99991            1680816                      128
# 99992            2166362                      113
# 99993            1289132                      123
# 99994            2034561                      132
# 99995            1204309                       87
# 99996            1490657                      128
# 99997            4455215                       17
# 99998            1895374                      165
# 99999            3100363                      130
#
#        ip_device_os_by_app_countuniq  ip_by_hour_countuniq  \
# 0                                 51                    24
# 1                                 48                    24
# 2                                 42                    24
# 3                                 63                    24
# 4                                 28                    22
# 5                                 20                    24
# 6                                  4                    24
# 7                                 30                    23
# 8                                 22                    23
# 9                                 20                    24
# 10                                20                    19
# 11                                34                    24
# 12                                38                    24
# 13                                14                    24
# 14                                26                    24
# 15                                33                    24
# 16                                25                    24
# 17                                25                    18
# 18                                24                    19
# 19                                32                    24
# 20                                21                    23
# 21                                20                    24
# 22                                34                    24
# 23                                38                    24
# 24                                25                    24
# 25                                 3                    11
# 26                                23                    24
# 27                                49                    24
# 28                                16                    24
# 29                                26                    24
# ...                              ...                   ...
# 99970                             33                    24
# 99971                              1                    12
# 99972                             29                    24
# 99973                             31                    24
# 99974                             30                    24
# 99975                             21                    24
# 99976                             22                    24
# 99977                             16                    23
# 99978                             16                    24
# 99979                             42                    24
# 99980                             16                    24
# 99981                             59                    24
# 99982                             27                    24
# 99983                             21                    24
# 99984                             27                    24
# 99985                             62                    24
# 99986                             38                    24
# 99987                             31                    24
# 99988                             34                    24
# 99989                             36                    24
# 99990                             21                    24
# 99991                             39                    24
# 99992                             29                    24
# 99993                             19                    24
# 99994                             49                    24
# 99995                             25                    24
# 99996                             37                    24
# 99997                             10                     3
# 99998                             89                    24
# 99999                             22                    24
#
#        ip_by_app_countuniq  ip_app_by_os_countuniq  ip_by_device_countuniq  \
# 0                       90                      48                      30
# 1                       81                      51                      29
# 2                       73                      52                      19
# 3                      164                      71                     122
# 4                       38                      21                       5
# 5                       50                      31                       2
# 6                       46                      39                      13
# 7                       41                      30                       5
# 8                       33                      32                       6
# 9                       50                      17                       8
# 10                      67                      51                      11
# 11                      83                      56                      30
# 12                      59                      51                      14
# 13                      34                      19                       5
# 14                      44                      40                       4
# 15                      46                      36                       5
# 16                      39                      27                       5
# 17                      28                      12                       2
# 18                      35                      16                       5
# 19                      48                      42                      12
# 20                      37                      24                       3
# 21                      49                      29                       9
# 22                     192                      85                     239
# 23                      95                      54                      37
# 24                      40                      30                       6
# 25                      17                       5                       2
# 26                      56                      39                      15
# 27                     119                     104                      50
# 28                      43                      37                       6
# 29                      33                      26                       6
# ...                    ...                     ...                     ...
# 99970                   48                      40                       9
# 99971                   22                       3                       4
# 99972                  158                      12                     145
# 99973                   79                      41                      22
# 99974                   89                      43                      23
# 99975                   67                      36                      16
# 99976                   50                      20                       6
# 99977                   43                      20                       7
# 99978                   59                      44                      14
# 99979                   93                      92                      32
# 99980                   54                      36                      13
# 99981                  175                      90                     192
# 99982                   53                      20                      11
# 99983                   54                      32                       5
# 99984                   38                      16                       4
# 99985                  210                     152                     197
# 99986                   83                      43                      34
# 99987                   86                      23                      33
# 99988                  183                      95                     240
# 99989                   65                      50                      23
# 99990                   30                       8                       3
# 99991                   82                      49                      29
# 99992                   45                      32                       7
# 99993                   61                      33                      19
# 99994                   76                      45                      20
# 99995                   31                      39                       5
# 99996                   67                      33                      22
# 99997                   14                       1                       2
# 99998                  219                      62                     206
# 99999                   68                      41                      19
#
#        app_by_channel_countuniq  cumcount_ip_dev_os_by_app  cumcount_ip_by_os
# 0                            50                          0                  0
# 1                            50                          0                  0
# 2                            50                          0                  0
# 3                            40                          0                  0
# 4                            50                          0                  0
# 5                            50                          0                  0
# 6                            50                          0                  0
# 7                            50                          0                  0
# 8                            50                          0                  0
# 9                             3                          0                  0
# 10                           50                          0                  0
# 11                           50                          0                  0
# 12                           50                          0                  0
# 13                           50                          0                  0
# 14                           50                          0                  0
# 15                           50                          0                  0
# 16                           50                          0                  0
# 17                           50                          0                  0
# 18                           50                          0                  0
# 19                           50                          0                  0
# 20                           50                          0                  0
# 21                           50                          0                  0
# 22                           40                          0                  0
# 23                           50                          0                  0
# 24                           50                          0                  0
# 25                           50                          0                  0
# 26                           50                          0                  0
# 27                           50                          0                  0
# 28                           50                          0                  0
# 29                           50                          0                  0
# ...                         ...                        ...                ...
# 99970                        33                          0                  2
# 99971                        28                          0                  0
# 99972                         9                          0                 28
# 99973                        47                          2                  9
# 99974                        40                         13                 20
# 99975                        47                          1                 12
# 99976                        33                          3                  3
# 99977                        47                         33                 33
# 99978                        50                          0                  0
# 99979                        33                         13                 29
# 99980                        31                          4                  4
# 99981                        47                         35                137
# 99982                         4                          3                  3
# 99983                        47                          2                  6
# 99984                         9                          3                  3
# 99985                        33                         21                560
# 99986                         9                          3                  5
# 99987                         4                          4                  4
# 99988                        47                          2                 68
# 99989                        11                          0                  0
# 99990                         4                          2                  2
# 99991                        50                          0                  6
# 99992                        28                         16                 16
# 99993                        28                          0                  1
# 99994                        28                          2                  5
# 99995                        31                          0                  0
# 99996                        33                          5                  6
# 99997                         4                          2                  2
# 99998                         3                        141                609
# 99999                        33                          4                  4
#
# [100000 rows x 24 columns]

# %%
concat_df = do_next_Click(concat_df)
gc.collect()
# Out:
# >>
# Extracting nextClick time calculation features...
#
# >> Grouping by ['ip'], and saving time to nextClick in: ip_nextClick
# >> Grouping by ['ip', 'app'], and saving time to nextClick in: ip_app_nextClick
# >> Grouping by ['ip', 'channel'], and saving time to nextClick in: ip_channel_nextClick
# >> Grouping by ['ip', 'os'], and saving time to nextClick in: ip_os_nextClick
# >> Grouping by ['ip', 'app', 'device', 'os', 'channel'], and saving time to nextClick in: ip_app_device_os_channel_nextClick
# >> Grouping by ['ip', 'os', 'device'], and saving time to nextClick in: ip_os_device_nextClick
# >> Grouping by ['ip', 'os', 'device', 'app'], and saving time to nextClick in: ip_os_device_app_nextClick
# [Adding next click times] done in 11198 s
# 0

# %%
train_df = concat_df.iloc[:num_train]
testsup_df = concat_df.iloc[num_train:]

del concat_df
gc.collect()
# Out:
# 35

# %%
import sys

print("{}{: >25}{}{: >10}{}".format('|','Variable Name','|','Memory','|'))
print(" ------------------------------------ ")
for var_name in dir():
    if not var_name.startswith("_"):
        print("{}{: >25}{}{: >10}{}".format('|',var_name,'|',sys.getsizeof(eval(var_name)),'|'))
gc.collect()
# Out:
# |            Variable Name|    Memory|
#  ------------------------------------
# |                       In|       344|
# |                      Out|       648|
# |         bagging_fraction|        24|
# |             bagging_freq|        28|
# | bin_construct_sample_cnt|        28|
# |              categorical|       104|
# |                  columns|       120|
# |            common_column|       112|
# |           contextmanager|       136|
# |            df_add_counts|       136|
# |             do_countuniq|       136|
# |              do_cumcount|       136|
# |            do_next_Click|       136|
# |                   dtypes|       368|
# |    early_stopping_rounds|        28|
# |            evals_results|       240|
# |                     exit|        56|
# |                        f|       176|
# |         feature_fraction|        24|
# |                       gc|        80|
# |              get_ipython|        64|
# |                      lgb|        80|
# |               lgb_params|       648|
# |      make_count_features|       136|
# |  make_countuniq_features|       136|
# |                  max_bin|        28|
# |                max_depth|        28|
# |         min_data_in_leaf|        28|
# |              min_hessian|        24|
# |                       np|        80|
# |          num_boost_round|        28|
# |                num_train|        28|
# |                     path|        69|
# |                       pd|        80|
# |                   pickle|        80|
# |                      plt|        80|
# |               predictors|       368|
# |                     quit|        56|
# |         scale_pos_weight|        28|
# |                      sys|        80|
# |                   target|        62|
# |                     time|        80|
# |                    timer|       136|
# |         train_test_split|       136|
# |                 var_name|        57|
# |                  x_train|25461265677|
# |                    x_val|2829029541|
# |                  y_train| 166413597|
# |                    y_val|  18490485|
# 57

# %%
# データ保存
with open('train_add_features.csv.pkl','wb') as f:
  pickle.dump(train_df,f,protocol=4)

with open('testsup_add_features.csv.pkl','wb') as f:
  pickle.dump(testsup_df,f,protocol=4)

with open('y.csv.pkl','wb') as f:
  pickle.dump(y, f, protocol=4)

# %%
#データ読みこみ
with open('train_add_features.csv.pkl','rb') as f:
  train_df = pickle.load(f)

# with open('testsup_after.csv.pkl','rb') as f:
#   testsup_df = pickle.load(f)

with open('y.csv.pkl','rb') as f:
  y = pickle.load(f)

# %%
x_train, x_val, y_train, y_val = train_test_split(train_df, y, train_size=0.9, random_state=0)

del train_df, y
gc.collect()
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# 165

# %%
evals_results = {}
# num_boost_round = 250
# early_stopping_rounds = 30
num_boost_round = 10000
early_stopping_rounds = 50

# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'subsample_for_bin': 200000,  # Number of samples for constructing bin
#     'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
#     'reg_alpha': 0,  # L1 regularization term on weights
#     'reg_lambda': 0,  # L2 regularization term on weights
#     'nthread': 8,
#     'verbose': 0,
#     'metric':'auc',     
 
#     'learning_rate': 0.15,
#     'num_leaves': 7,  # 2^max_depth - 1
#     'max_depth': 3,  # -1 means no limit
#     'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
#     'max_bin': 100,  # Number of bucketed bin for feature values
#     'subsample': 0.7,  # Subsample ratio of the training instance.
#     'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
#     'colsample_bytree': 0.9,  # Subsample ratio of columns when constructing each tree.
#     'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
#     'scale_pos_weight':99
# }

# matsuda Hyperparameters
min_data_in_leaf = 100
# min_data_in_leaf = 50
max_bin = 127
bagging_fraction = 0.7
bagging_freq = 1 
feature_fraction = 0.9
bin_construct_sample_cnt = 100000
min_hessian = 0 
scale_pos_weight = 200
max_depth = -1

lgb_params = {
   'boosting_type': 'gbdt',
   'objective': 'binary',
   'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
   'nthread': 16,
   'verbose': 0,
   'metric': 'auc',
   'learning_rate': 0.05,
#    'learning_rate': 0.1,
   'max_depth': max_depth,  # -1 means no limit
   'num_leaves': 31,  # 2^max_depth - 1
   'min_child_samples': min_data_in_leaf,  # Minimum number of data need in a child(min_data_in_leaf)
   'max_bin': max_bin,  # Number of bucketed bin for feature values
   'bin_construct_sample_cnt': bin_construct_sample_cnt,
   # 'subsample_for_bin': 20000,  # Number of samples for constructing bin
   'bagging_fraction': bagging_fraction,  # subsample
   'bagging_freq': bagging_freq,  # subsample_freq
   'feature_fraction': feature_fraction,  # colsample_bytree
   'min_sum_hessian_in_leaf': min_hessian,  # min_child_weight
   'scale_pos_weight': scale_pos_weight
}


# metrics = 'auc'
# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': metrics,
#     'learning_rate': .1,
#     'num_leaves': 7,
#     'max_depth': 4,
#     'min_child_samples': 100,
#     'max_bin': 100,
#     'subsample': 0.7,
#     'subsample_freq': 1,
#     'colsample_bytree': 0.7,
#     'min_child_weight': 0,
#     'min_split_gain': 0,
#     'nthread': 4,
#     'verbose': 1,
#     'scale_pos_weight': 99.7
#     #'scale_pos_weight': 400
# }

# %%
# del testsup_df
gc.collect()
# Out:
# 0

# %%
target = "is_attributed"
categorical = ['app','os','channel','hour','device']
predictors = list(set(x_train.columns)-set([target])-set(['click_time','ip']))
print(predictors)

print("preparing validation datasets")

xgtrain = lgb.Dataset(x_train[predictors].values,
                      label=y_train,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_train
del y_train
gc.collect()

xgvalid = lgb.Dataset(x_val[predictors].values,
                      label=y_val,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_val
del y_val
gc.collect()
# Out:
# ['app_channel_count', 'ip_by_hour_countuniq', 'device', 'os_app_channel_count', 'ip_count', 'cumcount_ip_by_os', 'os_device_count', 'ip_app_count', 'ip_os_nextClick', 'ip_os_device_nextClick', 'hour', 'ip_by_device_countuniq', 'ip_os_device_app_nextClick', 'os', 'ip_app_os_count', 'ip_nextClick', 'ip_app_nextClick', 'ip_by_app_countuniq', 'ip_app_device_os_channel_nextClick', 'ip_app_by_os_countuniq', 'cumcount_ip_dev_os_by_app', 'app', 'app_by_channel_countuniq', 'ip_device_count', 'ip_by_channel_countuniq', 'ip_channel_nextClick', 'channel', 'ip_hour_count', 'ip_device_os_by_app_countuniq']
# preparing validation datasets
# 33

# %%
x_train.head()
# Out:
#               ip  app  device  os  channel          click_time  hour  \
# 31680685   15878   12       1  19      245 2017-11-07 06:46:20     6
# 57989117  109735   26       1  27      121 2017-11-07 15:22:30    15
# 92371941  123994   14       1  13      379 2017-11-08 07:08:09     7
# 14397593  101800   35       1  26      274 2017-11-07 01:26:19     1
# 75324357  127583   23       1   9      153 2017-11-08 01:56:23     1
#
#           ip_count  os_device_count  os_app_channel_count  \
# 31680685      2409         56240944                748282
# 57989117     65926          2169288                 20638
# 92371941    220664         49858614                514837
# 14397593      4062          1120952                   105
# 75324357      3997          4318346                 66929
#
#                      ...              app_by_channel_countuniq  \
# 31680685             ...                                    33
# 57989117             ...                                     5
# 92371941             ...                                    40
# 14397593             ...                                     6
# 75324357             ...                                    11
#
#           cumcount_ip_dev_os_by_app  cumcount_ip_by_os  ip_nextClick  \
# 31680685                        212                668           0.0
# 57989117                        122              15071           2.0
# 92371941                      12847                124           1.0
# 14397593                          0                183         384.0
# 75324357                         29               1818           1.0
#
#           ip_app_nextClick  ip_channel_nextClick  ip_os_nextClick  \
# 31680685              45.0                   0.0              0.0
# 57989117              15.0                  15.0             16.0
# 92371941               4.0                   9.0              6.0
# 14397593           41362.0               52768.0          49052.0
# 75324357            1278.0                1278.0            743.0
#
#           ip_app_device_os_channel_nextClick  ip_os_device_nextClick  \
# 31680685                                 NaN                     0.0
# 57989117                             56067.0                    16.0
# 92371941                              3092.0                     6.0
# 14397593                                 NaN                 49052.0
# 75324357                              1278.0                   743.0
#
#           ip_os_device_app_nextClick
# 31680685                       500.0
# 57989117                     56067.0
# 92371941                         8.0
# 14397593                         NaN
# 75324357                      1278.0
#
# [5 rows x 31 columns]

# %%
# gc.collect()
# del booster
booster = lgb.train(
     lgb_params, 
     xgtrain,
     valid_sets=[xgvalid],
     valid_names=['valid'],
     evals_result=evals_results, 
     num_boost_round=num_boost_round,
     early_stopping_rounds=early_stopping_rounds,
     verbose_eval=1
)

del xgvalid
del xgtrain
gc.collect()
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	valid's auc: 0.969253
# Training until validation scores don't improve for 50 rounds.
# [2]	valid's auc: 0.970247
# [3]	valid's auc: 0.971507
# [4]	valid's auc: 0.971992
# [5]	valid's auc: 0.972409
# [6]	valid's auc: 0.972895
# [7]	valid's auc: 0.973078
# [8]	valid's auc: 0.973891
# [9]	valid's auc: 0.97403
# [10]	valid's auc: 0.974434
# [11]	valid's auc: 0.974681
# [12]	valid's auc: 0.97505
# [13]	valid's auc: 0.975187
# [14]	valid's auc: 0.975251
# [15]	valid's auc: 0.975266
# [16]	valid's auc: 0.975419
# [17]	valid's auc: 0.975592
# [18]	valid's auc: 0.975621
# [19]	valid's auc: 0.975935
# [20]	valid's auc: 0.975877
# [21]	valid's auc: 0.976069
# [22]	valid's auc: 0.976171
# [23]	valid's auc: 0.976281
# [24]	valid's auc: 0.976366
# [25]	valid's auc: 0.976532
# [26]	valid's auc: 0.976822
# [27]	valid's auc: 0.977226
# [28]	valid's auc: 0.977425
# [29]	valid's auc: 0.977588
# [30]	valid's auc: 0.977756
# [31]	valid's auc: 0.977899
# [32]	valid's auc: 0.978008
# [33]	valid's auc: 0.978091
# [34]	valid's auc: 0.978225
# [35]	valid's auc: 0.978272
# [36]	valid's auc: 0.97836
# [37]	valid's auc: 0.978471
# [38]	valid's auc: 0.978552
# [39]	valid's auc: 0.978631
# [40]	valid's auc: 0.978723
# [41]	valid's auc: 0.97881
# [42]	valid's auc: 0.978903
# [43]	valid's auc: 0.978991
# [44]	valid's auc: 0.979246
# [45]	valid's auc: 0.97931
# [46]	valid's auc: 0.979444
# [47]	valid's auc: 0.979512
# [48]	valid's auc: 0.979579
# [49]	valid's auc: 0.979648
# [50]	valid's auc: 0.979711
# [51]	valid's auc: 0.979785
# [52]	valid's auc: 0.979919
# [53]	valid's auc: 0.979958
# [54]	valid's auc: 0.980139
# [55]	valid's auc: 0.980284
# [56]	valid's auc: 0.980431
# [57]	valid's auc: 0.980529
# [58]	valid's auc: 0.980565
# [59]	valid's auc: 0.980609
# [60]	valid's auc: 0.980703
# [61]	valid's auc: 0.980758
# [62]	valid's auc: 0.980875
# [63]	valid's auc: 0.980957
# [64]	valid's auc: 0.981049
# [65]	valid's auc: 0.981131
# [66]	valid's auc: 0.981162
# [67]	valid's auc: 0.981224
# [68]	valid's auc: 0.981295
# [69]	valid's auc: 0.981384
# [70]	valid's auc: 0.981468
# [71]	valid's auc: 0.981529
# [72]	valid's auc: 0.981614
# [73]	valid's auc: 0.981676
# [74]	valid's auc: 0.981727
# [75]	valid's auc: 0.98177
# [76]	valid's auc: 0.981837
# [77]	valid's auc: 0.981885
# [78]	valid's auc: 0.981947
# [79]	valid's auc: 0.981987
# [80]	valid's auc: 0.982061
# [81]	valid's auc: 0.982122
# [82]	valid's auc: 0.982171
# [83]	valid's auc: 0.982228
# [84]	valid's auc: 0.982282
# [85]	valid's auc: 0.982326
# [86]	valid's auc: 0.982373
# [87]	valid's auc: 0.982411
# [88]	valid's auc: 0.982456
# [89]	valid's auc: 0.982503
# [90]	valid's auc: 0.982554
# [91]	valid's auc: 0.982611
# [92]	valid's auc: 0.982663
# [93]	valid's auc: 0.98271
# [94]	valid's auc: 0.982752
# [95]	valid's auc: 0.982791
# [96]	valid's auc: 0.98283
# [97]	valid's auc: 0.982865
# [98]	valid's auc: 0.982898
# [99]	valid's auc: 0.982942
# [100]	valid's auc: 0.982987
# [101]	valid's auc: 0.983031
# [102]	valid's auc: 0.983073
# [103]	valid's auc: 0.983105
# [104]	valid's auc: 0.983132
# [105]	valid's auc: 0.983165
# [106]	valid's auc: 0.983192
# [107]	valid's auc: 0.983223
# [108]	valid's auc: 0.983249
# [109]	valid's auc: 0.98327
# [110]	valid's auc: 0.983298
# [111]	valid's auc: 0.983323
# [112]	valid's auc: 0.983351
# [113]	valid's auc: 0.983383
# [114]	valid's auc: 0.983401
# [115]	valid's auc: 0.983434
# [116]	valid's auc: 0.983459
# [117]	valid's auc: 0.983482
# [118]	valid's auc: 0.983505
# [119]	valid's auc: 0.983525
# [120]	valid's auc: 0.983548
# [121]	valid's auc: 0.983562
# [122]	valid's auc: 0.983588
# [123]	valid's auc: 0.983608
# [124]	valid's auc: 0.983628
# [125]	valid's auc: 0.983648
# [126]	valid's auc: 0.983671
# [127]	valid's auc: 0.983685
# [128]	valid's auc: 0.983704
# [129]	valid's auc: 0.983719
# [130]	valid's auc: 0.983732
# [131]	valid's auc: 0.983751
# [132]	valid's auc: 0.983772
# [133]	valid's auc: 0.98379
# [134]	valid's auc: 0.983806
# [135]	valid's auc: 0.983825
# [136]	valid's auc: 0.983845
# [137]	valid's auc: 0.983859
# [138]	valid's auc: 0.983867
# [139]	valid's auc: 0.983882
# [140]	valid's auc: 0.983893
# [141]	valid's auc: 0.983923
# [142]	valid's auc: 0.983939
# [143]	valid's auc: 0.983954
# [144]	valid's auc: 0.983968
# [145]	valid's auc: 0.983976
# [146]	valid's auc: 0.983989
# [147]	valid's auc: 0.983992
# [148]	valid's auc: 0.984011
# [149]	valid's auc: 0.98402
# [150]	valid's auc: 0.984033
# [151]	valid's auc: 0.984044
# [152]	valid's auc: 0.984046
# [153]	valid's auc: 0.984062
# [154]	valid's auc: 0.984077
# [155]	valid's auc: 0.984087
# [156]	valid's auc: 0.984098
# [157]	valid's auc: 0.98411
# [158]	valid's auc: 0.984121
# [159]	valid's auc: 0.984125
# [160]	valid's auc: 0.984133
# [161]	valid's auc: 0.98414
# [162]	valid's auc: 0.984145
# [163]	valid's auc: 0.98416
# [164]	valid's auc: 0.984168
# [165]	valid's auc: 0.984185
# [166]	valid's auc: 0.984194
# [167]	valid's auc: 0.984202
# [168]	valid's auc: 0.984209
# [169]	valid's auc: 0.984217
# [170]	valid's auc: 0.984229
# [171]	valid's auc: 0.984235
# [172]	valid's auc: 0.984248
# [173]	valid's auc: 0.984256
# [174]	valid's auc: 0.984269
# [175]	valid's auc: 0.984279
# [176]	valid's auc: 0.98429
# [177]	valid's auc: 0.9843
# [178]	valid's auc: 0.984305
# [179]	valid's auc: 0.984316
# [180]	valid's auc: 0.984323
# [181]	valid's auc: 0.984328
# [182]	valid's auc: 0.984338
# [183]	valid's auc: 0.984344
# [184]	valid's auc: 0.984353
# [185]	valid's auc: 0.984363
# [186]	valid's auc: 0.984372
# [187]	valid's auc: 0.984382
# [188]	valid's auc: 0.984386
# [189]	valid's auc: 0.984393
# [190]	valid's auc: 0.984399
# [191]	valid's auc: 0.984408
# [192]	valid's auc: 0.984415
# [193]	valid's auc: 0.984422
# [194]	valid's auc: 0.984425
# [195]	valid's auc: 0.984428
# [196]	valid's auc: 0.984432
# [197]	valid's auc: 0.984437
# [198]	valid's auc: 0.984441
# [199]	valid's auc: 0.984444
# [200]	valid's auc: 0.984446
# [201]	valid's auc: 0.984449
# [202]	valid's auc: 0.984454
# [203]	valid's auc: 0.984462
# [204]	valid's auc: 0.984477
# [205]	valid's auc: 0.984481
# [206]	valid's auc: 0.984488
# [207]	valid's auc: 0.984497
# [208]	valid's auc: 0.984502
# [209]	valid's auc: 0.984507
# [210]	valid's auc: 0.98451
# [211]	valid's auc: 0.984514
# [212]	valid's auc: 0.98452
# [213]	valid's auc: 0.984522
# [214]	valid's auc: 0.984524
# [215]	valid's auc: 0.984528
# [216]	valid's auc: 0.984534
# [217]	valid's auc: 0.984537
# [218]	valid's auc: 0.984542
# [219]	valid's auc: 0.98455
# [220]	valid's auc: 0.984556
# [221]	valid's auc: 0.984562
# [222]	valid's auc: 0.98457
# [223]	valid's auc: 0.984577
# [224]	valid's auc: 0.984578
# [225]	valid's auc: 0.984584
# [226]	valid's auc: 0.984589
# [227]	valid's auc: 0.984593
# [228]	valid's auc: 0.984595
# [229]	valid's auc: 0.984604
# [230]	valid's auc: 0.984609
# [231]	valid's auc: 0.984609
# [232]	valid's auc: 0.984612
# [233]	valid's auc: 0.984615
# [234]	valid's auc: 0.984619
# [235]	valid's auc: 0.98462
# [236]	valid's auc: 0.984625
# [237]	valid's auc: 0.984624
# [238]	valid's auc: 0.98463
# [239]	valid's auc: 0.984633
# [240]	valid's auc: 0.984638
# [241]	valid's auc: 0.984643
# [242]	valid's auc: 0.984643
# [243]	valid's auc: 0.984645
# [244]	valid's auc: 0.98465
# [245]	valid's auc: 0.98465
# [246]	valid's auc: 0.984656
# [247]	valid's auc: 0.984657
# [248]	valid's auc: 0.98466
# [249]	valid's auc: 0.984664
# [250]	valid's auc: 0.984668
# [251]	valid's auc: 0.98467
# [252]	valid's auc: 0.984672
# [253]	valid's auc: 0.984672
# [254]	valid's auc: 0.984675
# [255]	valid's auc: 0.984683
# [256]	valid's auc: 0.984692
# [257]	valid's auc: 0.984696
# [258]	valid's auc: 0.984699
# [259]	valid's auc: 0.984702
# [260]	valid's auc: 0.984708
# [261]	valid's auc: 0.984713
# [262]	valid's auc: 0.984716
# [263]	valid's auc: 0.984717
# [264]	valid's auc: 0.984717
# [265]	valid's auc: 0.984723
# [266]	valid's auc: 0.984723
# [267]	valid's auc: 0.984723
# [268]	valid's auc: 0.984723
# [269]	valid's auc: 0.984726
# [270]	valid's auc: 0.984729
# [271]	valid's auc: 0.98473
# [272]	valid's auc: 0.984732
# [273]	valid's auc: 0.984741
# [274]	valid's auc: 0.984743
# [275]	valid's auc: 0.984744
# [276]	valid's auc: 0.984745
# [277]	valid's auc: 0.984747
# [278]	valid's auc: 0.984748
# [279]	valid's auc: 0.984756
# [280]	valid's auc: 0.984756
# [281]	valid's auc: 0.984758
# [282]	valid's auc: 0.984762
# [283]	valid's auc: 0.984765
# [284]	valid's auc: 0.984766
# [285]	valid's auc: 0.984766
# [286]	valid's auc: 0.984767
# [287]	valid's auc: 0.984769
# [288]	valid's auc: 0.984771
# [289]	valid's auc: 0.984772
# [290]	valid's auc: 0.984775
# [291]	valid's auc: 0.98478
# [292]	valid's auc: 0.984782
# [293]	valid's auc: 0.984783
# [294]	valid's auc: 0.984783
# [295]	valid's auc: 0.984786
# [296]	valid's auc: 0.984786
# [297]	valid's auc: 0.984785
# [298]	valid's auc: 0.984785
# [299]	valid's auc: 0.984786
# [300]	valid's auc: 0.984788
# [301]	valid's auc: 0.984788
# [302]	valid's auc: 0.98479
# [303]	valid's auc: 0.984792
# [304]	valid's auc: 0.984794
# [305]	valid's auc: 0.984802
# [306]	valid's auc: 0.984804
# [307]	valid's auc: 0.984805
# [308]	valid's auc: 0.984807
# [309]	valid's auc: 0.984809
# [310]	valid's auc: 0.984808
# [311]	valid's auc: 0.984811
# [312]	valid's auc: 0.984811
# [313]	valid's auc: 0.98481
# [314]	valid's auc: 0.984812
# [315]	valid's auc: 0.984812
# [316]	valid's auc: 0.984816
# [317]	valid's auc: 0.984822
# [318]	valid's auc: 0.984822
# [319]	valid's auc: 0.984825
# [320]	valid's auc: 0.984826
# [321]	valid's auc: 0.984828
# [322]	valid's auc: 0.984828
# [323]	valid's auc: 0.984828
# [324]	valid's auc: 0.984829
# [325]	valid's auc: 0.984834
# [326]	valid's auc: 0.984835
# [327]	valid's auc: 0.984837
# [328]	valid's auc: 0.984837
# [329]	valid's auc: 0.984839
# [330]	valid's auc: 0.984839
# [331]	valid's auc: 0.984843
# [332]	valid's auc: 0.984846
# [333]	valid's auc: 0.984845
# [334]	valid's auc: 0.984845
# [335]	valid's auc: 0.984847
# [336]	valid's auc: 0.984849
# [337]	valid's auc: 0.984851
# [338]	valid's auc: 0.984854
# [339]	valid's auc: 0.984854
# [340]	valid's auc: 0.984855
# [341]	valid's auc: 0.984856
# [342]	valid's auc: 0.984858
# [343]	valid's auc: 0.984859
# [344]	valid's auc: 0.984861
# [345]	valid's auc: 0.984861
# [346]	valid's auc: 0.98486
# [347]	valid's auc: 0.984859
# [348]	valid's auc: 0.984861
# [349]	valid's auc: 0.984861
# [350]	valid's auc: 0.984863
# [351]	valid's auc: 0.984867
# [352]	valid's auc: 0.984868
# [353]	valid's auc: 0.984869
# [354]	valid's auc: 0.984868
# [355]	valid's auc: 0.984868
# [356]	valid's auc: 0.984871
# [357]	valid's auc: 0.984871
# [358]	valid's auc: 0.984874
# [359]	valid's auc: 0.984875
# [360]	valid's auc: 0.984876
# [361]	valid's auc: 0.984878
# [362]	valid's auc: 0.984878
# [363]	valid's auc: 0.98488
# [364]	valid's auc: 0.984885
# [365]	valid's auc: 0.984886
# [366]	valid's auc: 0.984888
# [367]	valid's auc: 0.984888
# [368]	valid's auc: 0.984892
# [369]	valid's auc: 0.984894
# [370]	valid's auc: 0.984893
# [371]	valid's auc: 0.984894
# [372]	valid's auc: 0.984894
# [373]	valid's auc: 0.984893
# [374]	valid's auc: 0.984896
# [375]	valid's auc: 0.984896
# [376]	valid's auc: 0.984896
# [377]	valid's auc: 0.984895
# [378]	valid's auc: 0.984896
# [379]	valid's auc: 0.9849
# [380]	valid's auc: 0.984901
# [381]	valid's auc: 0.984901
# [382]	valid's auc: 0.984904
# [383]	valid's auc: 0.984903
# [384]	valid's auc: 0.984904
# [385]	valid's auc: 0.984904
# [386]	valid's auc: 0.984908
# [387]	valid's auc: 0.984908
# [388]	valid's auc: 0.98491
# [389]	valid's auc: 0.984908
# [390]	valid's auc: 0.984909
# [391]	valid's auc: 0.984908
# [392]	valid's auc: 0.984907
# [393]	valid's auc: 0.984907
# [394]	valid's auc: 0.984911
# [395]	valid's auc: 0.984911
# [396]	valid's auc: 0.984911
# [397]	valid's auc: 0.984912
# [398]	valid's auc: 0.984913
# [399]	valid's auc: 0.984912
# [400]	valid's auc: 0.984913
# [401]	valid's auc: 0.984916
# [402]	valid's auc: 0.984918
# [403]	valid's auc: 0.984917
# [404]	valid's auc: 0.984915
# [405]	valid's auc: 0.984915
# [406]	valid's auc: 0.984917
# [407]	valid's auc: 0.984918
# [408]	valid's auc: 0.984921
# [409]	valid's auc: 0.984922
# [410]	valid's auc: 0.984922
# [411]	valid's auc: 0.984924
# [412]	valid's auc: 0.984924
# [413]	valid's auc: 0.984924
# [414]	valid's auc: 0.984924
# [415]	valid's auc: 0.984926
# [416]	valid's auc: 0.984928
# [417]	valid's auc: 0.984928
# [418]	valid's auc: 0.984931
# [419]	valid's auc: 0.984932
# [420]	valid's auc: 0.984932
# [421]	valid's auc: 0.984931
# [422]	valid's auc: 0.984931
# [423]	valid's auc: 0.984933
# [424]	valid's auc: 0.984933
# [425]	valid's auc: 0.984933
# [426]	valid's auc: 0.984933
# [427]	valid's auc: 0.984933
# [428]	valid's auc: 0.984938
# [429]	valid's auc: 0.984939
# [430]	valid's auc: 0.984939
# [431]	valid's auc: 0.984939
# [432]	valid's auc: 0.984938
# [433]	valid's auc: 0.984939
# [434]	valid's auc: 0.98494
# [435]	valid's auc: 0.984939
# [436]	valid's auc: 0.984938
# [437]	valid's auc: 0.984937
# [438]	valid's auc: 0.984939
# [439]	valid's auc: 0.984938
# [440]	valid's auc: 0.984939
# [441]	valid's auc: 0.98494
# [442]	valid's auc: 0.984939
# [443]	valid's auc: 0.98494
# [444]	valid's auc: 0.98494
# [445]	valid's auc: 0.98494
# [446]	valid's auc: 0.984939
# [447]	valid's auc: 0.98494
# [448]	valid's auc: 0.98494
# [449]	valid's auc: 0.984939
# [450]	valid's auc: 0.98494
# [451]	valid's auc: 0.98494
# [452]	valid's auc: 0.984939
# [453]	valid's auc: 0.984939
# [454]	valid's auc: 0.984939
# [455]	valid's auc: 0.984938
# [456]	valid's auc: 0.98494
# [457]	valid's auc: 0.984939
# [458]	valid's auc: 0.984941
# [459]	valid's auc: 0.98494
# [460]	valid's auc: 0.984942
# [461]	valid's auc: 0.98494
# [462]	valid's auc: 0.984941
# [463]	valid's auc: 0.98494
# [464]	valid's auc: 0.984941
# [465]	valid's auc: 0.98494
# [466]	valid's auc: 0.984939
# [467]	valid's auc: 0.984938
# [468]	valid's auc: 0.984938
# [469]	valid's auc: 0.984938
# [470]	valid's auc: 0.984941
# [471]	valid's auc: 0.984943
# [472]	valid's auc: 0.984943
# [473]	valid's auc: 0.984943
# [474]	valid's auc: 0.984943
# [475]	valid's auc: 0.984944
# [476]	valid's auc: 0.984942
# [477]	valid's auc: 0.984942
# [478]	valid's auc: 0.984943
# [479]	valid's auc: 0.984945
# [480]	valid's auc: 0.984945
# [481]	valid's auc: 0.984945
# [482]	valid's auc: 0.984945
# [483]	valid's auc: 0.984945
# [484]	valid's auc: 0.984946
# [485]	valid's auc: 0.984946
# [486]	valid's auc: 0.984947
# [487]	valid's auc: 0.984948
# [488]	valid's auc: 0.984949
# [489]	valid's auc: 0.98495
# [490]	valid's auc: 0.984949
# [491]	valid's auc: 0.98495
# [492]	valid's auc: 0.98495
# [493]	valid's auc: 0.98495
# [494]	valid's auc: 0.984949
# [495]	valid's auc: 0.984948
# [496]	valid's auc: 0.984947
# [497]	valid's auc: 0.984947
# [498]	valid's auc: 0.984946
# [499]	valid's auc: 0.98495
# [500]	valid's auc: 0.984951
# [501]	valid's auc: 0.984951
# [502]	valid's auc: 0.984952
# [503]	valid's auc: 0.984951
# [504]	valid's auc: 0.984955
# [505]	valid's auc: 0.984954
# [506]	valid's auc: 0.984953
# [507]	valid's auc: 0.984952
# [508]	valid's auc: 0.984954
# [509]	valid's auc: 0.984953
# [510]	valid's auc: 0.984953
# [511]	valid's auc: 0.984954
# [512]	valid's auc: 0.984955
# [513]	valid's auc: 0.984955
# [514]	valid's auc: 0.984954
# [515]	valid's auc: 0.984954
# [516]	valid's auc: 0.984955
# [517]	valid's auc: 0.984953
# [518]	valid's auc: 0.984953
# [519]	valid's auc: 0.984953
# [520]	valid's auc: 0.984953
# [521]	valid's auc: 0.984954
# [522]	valid's auc: 0.984954
# [523]	valid's auc: 0.984953
# [524]	valid's auc: 0.984955
# [525]	valid's auc: 0.984959
# [526]	valid's auc: 0.98496
# [527]	valid's auc: 0.984959
# [528]	valid's auc: 0.984959
# [529]	valid's auc: 0.984958
# [530]	valid's auc: 0.984958
# [531]	valid's auc: 0.984958
# [532]	valid's auc: 0.984957
# [533]	valid's auc: 0.984956
# [534]	valid's auc: 0.984958
# [535]	valid's auc: 0.98496
# [536]	valid's auc: 0.98496
# [537]	valid's auc: 0.98496
# [538]	valid's auc: 0.98496
# [539]	valid's auc: 0.984961
# [540]	valid's auc: 0.984963
# [541]	valid's auc: 0.984965
# [542]	valid's auc: 0.984964
# [543]	valid's auc: 0.984965
# [544]	valid's auc: 0.984964
# [545]	valid's auc: 0.984965
# [546]	valid's auc: 0.984966
# [547]	valid's auc: 0.984966
# [548]	valid's auc: 0.984966
# [549]	valid's auc: 0.984966
# [550]	valid's auc: 0.984965
# [551]	valid's auc: 0.984964
# [552]	valid's auc: 0.984964
# [553]	valid's auc: 0.984964
# [554]	valid's auc: 0.984963
# [555]	valid's auc: 0.984964
# [556]	valid's auc: 0.984964
# [557]	valid's auc: 0.984963
# [558]	valid's auc: 0.984963
# [559]	valid's auc: 0.984962
# [560]	valid's auc: 0.984963
# [561]	valid's auc: 0.984963
# [562]	valid's auc: 0.984964
# [563]	valid's auc: 0.984963
# [564]	valid's auc: 0.984965
# [565]	valid's auc: 0.984965
# [566]	valid's auc: 0.984965
# [567]	valid's auc: 0.984965
# [568]	valid's auc: 0.984965
# [569]	valid's auc: 0.984966
# [570]	valid's auc: 0.984966
# [571]	valid's auc: 0.984966
# [572]	valid's auc: 0.984967
# [573]	valid's auc: 0.984968
# [574]	valid's auc: 0.984966
# [575]	valid's auc: 0.984967
# [576]	valid's auc: 0.984969
# [577]	valid's auc: 0.984969
# [578]	valid's auc: 0.984969
# [579]	valid's auc: 0.98497
# [580]	valid's auc: 0.98497
# [581]	valid's auc: 0.984971
# [582]	valid's auc: 0.984973
# [583]	valid's auc: 0.984973
# [584]	valid's auc: 0.984973
# [585]	valid's auc: 0.984974
# [586]	valid's auc: 0.984972
# [587]	valid's auc: 0.984973
# [588]	valid's auc: 0.984973
# [589]	valid's auc: 0.984973
# [590]	valid's auc: 0.984973
# [591]	valid's auc: 0.984972
# [592]	valid's auc: 0.984973
# [593]	valid's auc: 0.984973
# [594]	valid's auc: 0.984972
# [595]	valid's auc: 0.984973
# [596]	valid's auc: 0.984973
# [597]	valid's auc: 0.984973
# [598]	valid's auc: 0.984972
# [599]	valid's auc: 0.984972
# [600]	valid's auc: 0.984972
# [601]	valid's auc: 0.984974
# [602]	valid's auc: 0.984977
# [603]	valid's auc: 0.98498
# [604]	valid's auc: 0.984979
# [605]	valid's auc: 0.984979
# [606]	valid's auc: 0.984979
# [607]	valid's auc: 0.98498
# [608]	valid's auc: 0.984981
# [609]	valid's auc: 0.98498
# [610]	valid's auc: 0.984977
# [611]	valid's auc: 0.984978
# [612]	valid's auc: 0.984979
# [613]	valid's auc: 0.98498
# [614]	valid's auc: 0.984979
# [615]	valid's auc: 0.984978
# [616]	valid's auc: 0.98498
# [617]	valid's auc: 0.98498
# [618]	valid's auc: 0.98498
# [619]	valid's auc: 0.98498
# [620]	valid's auc: 0.98498
# [621]	valid's auc: 0.98498
# [622]	valid's auc: 0.98498
# [623]	valid's auc: 0.984979
# [624]	valid's auc: 0.984979
# [625]	valid's auc: 0.984978
# [626]	valid's auc: 0.984978
# [627]	valid's auc: 0.984979
# [628]	valid's auc: 0.984981
# [629]	valid's auc: 0.984983
# [630]	valid's auc: 0.984984
# [631]	valid's auc: 0.984983
# [632]	valid's auc: 0.984984
# [633]	valid's auc: 0.984984
# [634]	valid's auc: 0.984984
# [635]	valid's auc: 0.984984
# [636]	valid's auc: 0.984983
# [637]	valid's auc: 0.984983
# [638]	valid's auc: 0.984984
# [639]	valid's auc: 0.984984
# [640]	valid's auc: 0.984984
# [641]	valid's auc: 0.984984
# [642]	valid's auc: 0.984984
# [643]	valid's auc: 0.984984
# [644]	valid's auc: 0.984984
# [645]	valid's auc: 0.984984
# [646]	valid's auc: 0.984984
# [647]	valid's auc: 0.984983
# [648]	valid's auc: 0.984982
# [649]	valid's auc: 0.984981
# [650]	valid's auc: 0.98498
# [651]	valid's auc: 0.98498
# [652]	valid's auc: 0.98498
# [653]	valid's auc: 0.984983
# [654]	valid's auc: 0.984983
# [655]	valid's auc: 0.984983
# [656]	valid's auc: 0.984983
# [657]	valid's auc: 0.984983
# [658]	valid's auc: 0.984983
# [659]	valid's auc: 0.984984
# [660]	valid's auc: 0.984984
# [661]	valid's auc: 0.984983
# [662]	valid's auc: 0.984984
# [663]	valid's auc: 0.984983
# [664]	valid's auc: 0.984983
# [665]	valid's auc: 0.984981
# [666]	valid's auc: 0.984982
# [667]	valid's auc: 0.984984
# [668]	valid's auc: 0.984983
# [669]	valid's auc: 0.984983
# [670]	valid's auc: 0.984982
# [671]	valid's auc: 0.984981
# [672]	valid's auc: 0.984981
# [673]	valid's auc: 0.98498
# [674]	valid's auc: 0.98498
# [675]	valid's auc: 0.984981
# [676]	valid's auc: 0.984982
# [677]	valid's auc: 0.98498
# [678]	valid's auc: 0.984981
# [679]	valid's auc: 0.98498
# [680]	valid's auc: 0.984979
# [681]	valid's auc: 0.98498
# [682]	valid's auc: 0.984981
# [683]	valid's auc: 0.98498
# [684]	valid's auc: 0.98498
# [685]	valid's auc: 0.98498
# [686]	valid's auc: 0.98498
# [687]	valid's auc: 0.984979
# [688]	valid's auc: 0.984981
# [689]	valid's auc: 0.98498
# [690]	valid's auc: 0.98498
# [691]	valid's auc: 0.984984
# [692]	valid's auc: 0.984984
# [693]	valid's auc: 0.984983
# [694]	valid's auc: 0.984983
# [695]	valid's auc: 0.984983
# [696]	valid's auc: 0.984983
# [697]	valid's auc: 0.984983
# [698]	valid's auc: 0.984986
# [699]	valid's auc: 0.984986
# [700]	valid's auc: 0.984987
# [701]	valid's auc: 0.984988
# [702]	valid's auc: 0.984988
# [703]	valid's auc: 0.984988
# [704]	valid's auc: 0.984988
# [705]	valid's auc: 0.984987
# [706]	valid's auc: 0.984988
# [707]	valid's auc: 0.984988
# [708]	valid's auc: 0.984988
# [709]	valid's auc: 0.984989
# [710]	valid's auc: 0.984987
# [711]	valid's auc: 0.984989
# [712]	valid's auc: 0.984988
# [713]	valid's auc: 0.984986
# [714]	valid's auc: 0.984986
# [715]	valid's auc: 0.984986
# [716]	valid's auc: 0.984986
# [717]	valid's auc: 0.984987
# [718]	valid's auc: 0.984988
# [719]	valid's auc: 0.984986
# [720]	valid's auc: 0.984987
# [721]	valid's auc: 0.984988
# [722]	valid's auc: 0.98499
# [723]	valid's auc: 0.984989
# [724]	valid's auc: 0.984993
# [725]	valid's auc: 0.984993
# [726]	valid's auc: 0.984993
# [727]	valid's auc: 0.984993
# [728]	valid's auc: 0.984993
# [729]	valid's auc: 0.984994
# [730]	valid's auc: 0.984994
# [731]	valid's auc: 0.984993
# [732]	valid's auc: 0.984993
# [733]	valid's auc: 0.984993
# [734]	valid's auc: 0.984994
# [735]	valid's auc: 0.984995
# [736]	valid's auc: 0.984995
# [737]	valid's auc: 0.984994
# [738]	valid's auc: 0.984995
# [739]	valid's auc: 0.984996
# [740]	valid's auc: 0.984995
# [741]	valid's auc: 0.984997
# [742]	valid's auc: 0.984996
# [743]	valid's auc: 0.984997
# [744]	valid's auc: 0.984997
# [745]	valid's auc: 0.984996
# [746]	valid's auc: 0.984998
# [747]	valid's auc: 0.984999
# [748]	valid's auc: 0.984999
# [749]	valid's auc: 0.985002
# [750]	valid's auc: 0.985002
# [751]	valid's auc: 0.985002
# [752]	valid's auc: 0.985002
# [753]	valid's auc: 0.985003
# [754]	valid's auc: 0.985003
# [755]	valid's auc: 0.985002
# [756]	valid's auc: 0.985003
# [757]	valid's auc: 0.985002
# [758]	valid's auc: 0.985002
# [759]	valid's auc: 0.985003
# [760]	valid's auc: 0.985003
# [761]	valid's auc: 0.985003
# [762]	valid's auc: 0.985004
# [763]	valid's auc: 0.985005
# [764]	valid's auc: 0.985004
# [765]	valid's auc: 0.985003
# [766]	valid's auc: 0.985004
# [767]	valid's auc: 0.985003
# [768]	valid's auc: 0.985004
# [769]	valid's auc: 0.985004
# [770]	valid's auc: 0.985004
# [771]	valid's auc: 0.985005
# [772]	valid's auc: 0.985007
# [773]	valid's auc: 0.985006
# [774]	valid's auc: 0.985006
# [775]	valid's auc: 0.985006
# [776]	valid's auc: 0.985006
# [777]	valid's auc: 0.985007
# [778]	valid's auc: 0.985006
# [779]	valid's auc: 0.985006
# [780]	valid's auc: 0.985006
# [781]	valid's auc: 0.985003
# [782]	valid's auc: 0.985003
# [783]	valid's auc: 0.985003
# [784]	valid's auc: 0.985002
# [785]	valid's auc: 0.985002
# [786]	valid's auc: 0.985
# [787]	valid's auc: 0.985001
# [788]	valid's auc: 0.985002
# [789]	valid's auc: 0.985005
# [790]	valid's auc: 0.985005
# [791]	valid's auc: 0.985004
# [792]	valid's auc: 0.985004
# [793]	valid's auc: 0.985004
# [794]	valid's auc: 0.985003
# [795]	valid's auc: 0.985002
# [796]	valid's auc: 0.985002
# [797]	valid's auc: 0.985002
# [798]	valid's auc: 0.985002
# [799]	valid's auc: 0.985004
# [800]	valid's auc: 0.985005
# [801]	valid's auc: 0.985003
# [802]	valid's auc: 0.985002
# [803]	valid's auc: 0.985002
# [804]	valid's auc: 0.985002
# [805]	valid's auc: 0.985001
# [806]	valid's auc: 0.985001
# [807]	valid's auc: 0.985002
# [808]	valid's auc: 0.985002
# [809]	valid's auc: 0.985004
# [810]	valid's auc: 0.985005
# [811]	valid's auc: 0.985005
# [812]	valid's auc: 0.985006
# [813]	valid's auc: 0.985007
# [814]	valid's auc: 0.985011
# [815]	valid's auc: 0.98501
# [816]	valid's auc: 0.985012
# [817]	valid's auc: 0.985012
# [818]	valid's auc: 0.985009
# [819]	valid's auc: 0.985009
# [820]	valid's auc: 0.985009
# [821]	valid's auc: 0.98501
# [822]	valid's auc: 0.985011
# [823]	valid's auc: 0.985011
# [824]	valid's auc: 0.985012
# [825]	valid's auc: 0.985012
# [826]	valid's auc: 0.985012
# [827]	valid's auc: 0.98501
# [828]	valid's auc: 0.985011
# [829]	valid's auc: 0.985013
# [830]	valid's auc: 0.985014
# [831]	valid's auc: 0.985015
# [832]	valid's auc: 0.985015
# [833]	valid's auc: 0.985014
# [834]	valid's auc: 0.985013
# [835]	valid's auc: 0.985013
# [836]	valid's auc: 0.985013
# [837]	valid's auc: 0.985013
# [838]	valid's auc: 0.985014
# [839]	valid's auc: 0.985014
# [840]	valid's auc: 0.985013
# [841]	valid's auc: 0.985014
# [842]	valid's auc: 0.985014
# [843]	valid's auc: 0.985014
# [844]	valid's auc: 0.985014
# [845]	valid's auc: 0.985014
# [846]	valid's auc: 0.985016
# [847]	valid's auc: 0.985016
# [848]	valid's auc: 0.985017
# [849]	valid's auc: 0.985017
# [850]	valid's auc: 0.985018
# [851]	valid's auc: 0.985018
# [852]	valid's auc: 0.985018
# [853]	valid's auc: 0.985019
# [854]	valid's auc: 0.985019
# [855]	valid's auc: 0.985018
# [856]	valid's auc: 0.985018
# [857]	valid's auc: 0.985019
# [858]	valid's auc: 0.98502
# [859]	valid's auc: 0.985018
# [860]	valid's auc: 0.985018
# [861]	valid's auc: 0.985018
# [862]	valid's auc: 0.985018
# [863]	valid's auc: 0.985018
# [864]	valid's auc: 0.985018
# [865]	valid's auc: 0.985018
# [866]	valid's auc: 0.985017
# [867]	valid's auc: 0.985017
# [868]	valid's auc: 0.985017
# [869]	valid's auc: 0.985018
# [870]	valid's auc: 0.985017
# [871]	valid's auc: 0.985016
# [872]	valid's auc: 0.985016
# [873]	valid's auc: 0.985016
# [874]	valid's auc: 0.985016
# [875]	valid's auc: 0.985017
# [876]	valid's auc: 0.985018
# [877]	valid's auc: 0.985018
# [878]	valid's auc: 0.985017
# [879]	valid's auc: 0.985017
# [880]	valid's auc: 0.985016
# [881]	valid's auc: 0.985017
# [882]	valid's auc: 0.985019
# [883]	valid's auc: 0.985018
# [884]	valid's auc: 0.985017
# [885]	valid's auc: 0.985017
# [886]	valid's auc: 0.985017
# [887]	valid's auc: 0.985019
# [888]	valid's auc: 0.985021
# [889]	valid's auc: 0.985018
# [890]	valid's auc: 0.98502
# [891]	valid's auc: 0.98502
# [892]	valid's auc: 0.985018
# [893]	valid's auc: 0.985018
# [894]	valid's auc: 0.985019
# [895]	valid's auc: 0.985019
# [896]	valid's auc: 0.985017
# [897]	valid's auc: 0.985017
# [898]	valid's auc: 0.985017
# [899]	valid's auc: 0.985017
# [900]	valid's auc: 0.985018
# [901]	valid's auc: 0.985017
# [902]	valid's auc: 0.985016
# [903]	valid's auc: 0.985014
# [904]	valid's auc: 0.985014
# [905]	valid's auc: 0.985015
# [906]	valid's auc: 0.985015
# [907]	valid's auc: 0.985015
# [908]	valid's auc: 0.985015
# [909]	valid's auc: 0.985015
# [910]	valid's auc: 0.985014
# [911]	valid's auc: 0.985014
# [912]	valid's auc: 0.985014
# [913]	valid's auc: 0.985014
# [914]	valid's auc: 0.985014
# [915]	valid's auc: 0.985015
# [916]	valid's auc: 0.985016
# [917]	valid's auc: 0.985015
# [918]	valid's auc: 0.985015
# [919]	valid's auc: 0.985015
# [920]	valid's auc: 0.985014
# [921]	valid's auc: 0.985013
# [922]	valid's auc: 0.985014
# [923]	valid's auc: 0.985014
# [924]	valid's auc: 0.985015
# [925]	valid's auc: 0.985015
# [926]	valid's auc: 0.985017
# [927]	valid's auc: 0.985017
# [928]	valid's auc: 0.985017
# [929]	valid's auc: 0.985017
# [930]	valid's auc: 0.985017
# [931]	valid's auc: 0.985018
# [932]	valid's auc: 0.985019
# [933]	valid's auc: 0.985018
# [934]	valid's auc: 0.985019
# [935]	valid's auc: 0.985019
# [936]	valid's auc: 0.985018
# [937]	valid's auc: 0.985019
# [938]	valid's auc: 0.985019
# Early stopping, best iteration is:
# [888]	valid's auc: 0.985021
# 41

# %%
n_estimators = booster.best_iteration
metrics = 'auc'

print('\nModel Info:')
print('n_estimators:', n_estimators)
print(metrics+':', evals_results['valid'][metrics][n_estimators-1])
# Out:
# Model Info:
# n_estimators: 888
# auc: 0.9850206053420377

# %%
ax = lgb.plot_importance(booster, max_num_features=100)
plt.show()

# %%
ax = lgb.plot_importance(booster, importance_type='gain')
plt.show()

# %%
plt.savefig('0506-1-6imp.png', dpi=600, bbox_inches='tight')

# %%
gc.collect()
# Out:
# 6407

# %%
with timer("load test data"):
    test_df = pd.read_csv(path+"test.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load test data] done in 15 s

# %%
with open('testsup_add_features.csv.pkl','rb') as f:
  testsup_df = pickle.load(f)

# %%
test_df['click_time']= pd.to_datetime(test_df['click_time'])
testsup_df['click_time']= pd.to_datetime(testsup_df['click_time'])

# %%
# preditions=booster.predict(test_df[predictors].values)

gc.collect()

print("Predicting the submission data...")

testsup_df['is_attributed'] = booster.predict(testsup_df[predictors], num_iteration=booster.best_iteration)

print('projecting prediction onto test')

join_cols = ['ip', 'app', 'device', 'os', 'channel', 'click_time']
all_cols = join_cols + ['is_attributed']
# Out:
# Predicting the submission data...
# projecting prediction onto test

# %%
test_df = test_df.merge(testsup_df[all_cols], how='left', on=join_cols)

test_df = test_df.drop_duplicates(subset=['click_id'])

# %%
test_df.head()
# Out:
#    click_id      ip  app  device  os  channel          click_time  \
# 0         0    5744    9       1   3      107 2017-11-10 04:00:00
# 1         1  119901    9       1   3      466 2017-11-10 04:00:00
# 2         2   72287   21       1  19      128 2017-11-10 04:00:00
# 3         3   78477   15       1  13      111 2017-11-10 04:00:00
# 4         4  123080   12       1  13      328 2017-11-10 04:00:00
#
#    is_attributed
# 0       0.123792
# 1       0.010504
# 2       0.001260
# 3       0.041894
# 4       0.012116

# %%
test_df.count()
# Out:
# click_id         18790469
# ip               18790469
# app              18790469
# device           18790469
# os               18790469
# channel          18790469
# click_time       18790469
# is_attributed    18790469
# dtype: int64

# %%
print("Writing the submission data into a csv file...")

test_df[['click_id', 'is_attributed']].to_csv('0506-1-6.csv', index=False)

print("All done...")
# Out:
# Writing the submission data into a csv file...
# All done...
