# %% [markdown]
# train: 40m, validation 10%, suffle=true, categorical変数にday, hour, minute追加
# test_after.pkl testsup_after.pkl作成

# %%
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import gc
from contextlib import contextmanager
import pickle

# %%
@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f'[{name}] done in {time.time() - t0:.0f} s')
    
def df_add_counts(df, cols):
    arr_slice = df[cols].values
    unq, unqtags, counts = np.unique(np.ravel_multi_index(arr_slice.T, arr_slice.max(axis=0) + 1),
                                     return_inverse=True, return_counts=True)
    df["_".join(cols)+'_count'] = counts[unqtags]
    
def make_count_features(df):
    with timer("add count features"):
        df['click_time']= pd.to_datetime(df['click_time'])
        dt= df['click_time'].dt
        df['day'] = dt.day.astype('uint8')
        df['hour'] = dt.hour.astype('uint8')
        df['minute'] = dt.minute.astype('uint8')
#         df['second'] = dt.second.astype('uint8')#secondを追加

        del(dt)
        
        df_add_counts(df, ['ip'])
        df_add_counts(df, ['ip','day','hour','minute'])
        df_add_counts(df, ['os','device'])
        df_add_counts(df, ['os','app','channel'])
        
        df_add_counts(df, ['ip', 'day', 'hour'])
        df_add_counts(df, ['ip', 'app'])
        df_add_counts(df, ['ip', 'app', 'os'])
        df_add_counts(df, ['ip', 'device'])
        df_add_counts(df, ['app', 'channel'])

def make_next_click_feature(df):
    with timer("Adding next click times"):
        D= 2**26
        df['category'] = (df['ip'].astype(str) + "_" + df['app'].astype(str) + "_" + df['device'].astype(str) \
                         + "_" + df['os'].astype(str)).apply(hash) % D
        click_buffer= np.full(D, 3000000000, dtype=np.uint32)
        df['epochtime']= df['click_time'].astype(np.int64) // 10 ** 9
        next_clicks= []
        for category, time in zip(reversed(df['category'].values), reversed(df['epochtime'].values)):
            next_clicks.append(click_buffer[category]-time)
            click_buffer[category]= time
        del(click_buffer)
        df['next_click']= list(reversed(next_clicks))
        
path = '~/talkingdata/input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

# %%
with timer("load training data"):
    train_df = pd.read_csv(path+"train.csv", skiprows=range(1,144903891), nrows=40000000, usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)
# Out:
# [load training data] done in 153 s

# %%
with open('test.csv.pkl', 'rb') as f:
  test_df = pickle.load(f)
  print(test_df.head())
    
with open('testsup_without_test.csv.pkl', 'rb') as f:
  testsup_df = pickle.load(f)
  print(testsup_df.head())
# Out:
#    click_id      ip  app  device  os  channel           click_time
# 0         0    5744    9       1   3      107  2017-11-10 04:00:00
# 1         1  119901    9       1   3      466  2017-11-10 04:00:00
# 2         2   72287   21       1  19      128  2017-11-10 04:00:00
# 3         3   78477   15       1  13      111  2017-11-10 04:00:00
# 4         4  123080   12       1  13      328  2017-11-10 04:00:00
#    click_id      ip  app  device  os  channel           click_time  \
# 0         0   43570    3       1  18      379  2017-11-09 14:23:39
# 1         1   80528    3       1  13      379  2017-11-09 14:23:51
# 2         2   32323    3       1  13      379  2017-11-09 14:25:57
# 3         3   42887    3       1  17      379  2017-11-09 14:26:03
# 4         4  119289   58       1  30      120  2017-11-09 14:26:41
#
#    click_id.test
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# test_ip_max = test_df.ip.max()
# train_df = train_df[train_df.ip <= test_ip_max]
# print(len(train_df.index))
# print(train_df.ip.max())

# %%
test_df.head()
# Out:
#    click_id      ip  app  device  os  channel           click_time
# 0         0    5744    9       1   3      107  2017-11-10 04:00:00
# 1         1  119901    9       1   3      466  2017-11-10 04:00:00
# 2         2   72287   21       1  19      128  2017-11-10 04:00:00
# 3         3   78477   15       1  13      111  2017-11-10 04:00:00
# 4         4  123080   12       1  13      328  2017-11-10 04:00:00

# %%
testsup_df = testsup_df.drop("click_id.test", axis=1)
testsup_df.head()
# Out:
#    click_id      ip  app  device  os  channel           click_time
# 0         0   43570    3       1  18      379  2017-11-09 14:23:39
# 1         1   80528    3       1  13      379  2017-11-09 14:23:51
# 2         2   32323    3       1  13      379  2017-11-09 14:25:57
# 3         3   42887    3       1  17      379  2017-11-09 14:26:03
# 4         4  119289   58       1  30      120  2017-11-09 14:26:41

# %%
num_train = train_df.shape[0]
num_test = test_df.shape[0]
y = train_df.is_attributed.values

sub = pd.DataFrame()
sub['click_id'] = test_df.click_id.values

common_column = ['ip','app','device','os','channel','click_time']
concat_df = pd.concat([train_df[common_column],test_df[common_column],testsup_df[common_column]])

del train_df, testsup_df, test_df
gc.collect()
# Out:
# 138

# %%
make_count_features(concat_df)
make_next_click_feature(concat_df)

gc.collect()
# Out:
# [add count features] done in 690 s
# [Adding next click times] done in 669 s
# 28

# %%
train_df = concat_df.iloc[:num_train]
test_sup_df = concat_df.iloc[num_train:]
test_df = test_sup_df.iloc[:num_test]
testsup_df = test_sup_df.iloc[num_test:]
print(train_df.count())
print(test_df.count())
print(testsup_df.count())

del concat_df, test_sup_df

gc.collect()
# Out:
# ip                          40000000
# app                         40000000
# device                      40000000
# os                          40000000
# channel                     40000000
# click_time                  40000000
# day                         40000000
# hour                        40000000
# minute                      40000000
# ip_count                    40000000
# ip_day_hour_minute_count    40000000
# os_device_count             40000000
# os_app_channel_count        40000000
# ip_day_hour_count           40000000
# ip_app_count                40000000
# ip_app_os_count             40000000
# ip_device_count             40000000
# app_channel_count           40000000
# category                    40000000
# epochtime                   40000000
# next_click                  40000000
# dtype: int64
# ip                          18790469
# app                         18790469
# device                      18790469
# os                          18790469
# channel                     18790469
# click_time                  18790469
# day                         18790469
# hour                        18790469
# minute                      18790469
# ip_count                    18790469
# ip_day_hour_minute_count    18790469
# os_device_count             18790469
# os_app_channel_count        18790469
# ip_day_hour_count           18790469
# ip_app_count                18790469
# ip_app_os_count             18790469
# ip_device_count             18790469
# app_channel_count           18790469
# category                    18790469
# epochtime                   18790469
# next_click                  18790469
# dtype: int64
# ip                          39054755
# app                         39054755
# device                      39054755
# os                          39054755
# channel                     39054755
# click_time                  39054755
# day                         39054755
# hour                        39054755
# minute                      39054755
# ip_count                    39054755
# ip_day_hour_minute_count    39054755
# os_device_count             39054755
# os_app_channel_count        39054755
# ip_day_hour_count           39054755
# ip_app_count                39054755
# ip_app_os_count             39054755
# ip_device_count             39054755
# app_channel_count           39054755
# category                    39054755
# epochtime                   39054755
# next_click                  39054755
# dtype: int64
# 83

# %%
with open('test_after.csv.pkl','wb') as f:
  pickle.dump(test_df, f, protocol=2)

with open('testsup_after.csv.pkl','wb') as f:
  pickle.dump(testsup_df, f, protocol=2)

# %%
del testsup_df

# %%
train_df, val_df, y_train, y_val = train_test_split(train_df, y, train_size=0.9, random_state=0)
evals_results = {}
num_boost_round = 250
early_stopping_rounds = 30
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
lgb_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'subsample_for_bin': 200000,  # Number of samples for constructing bin
    'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
    'reg_alpha': 0,  # L1 regularization term on weights
    'reg_lambda': 0,  # L2 regularization term on weights
    'nthread': 4,
    'verbose': 0,
    'metric':'auc',     
 
    'learning_rate': 0.15,
    'num_leaves': 7,  # 2^max_depth - 1
    'max_depth': 3,  # -1 means no limit
    'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
    'max_bin': 100,  # Number of bucketed bin for feature values
    'subsample': 0.7,  # Subsample ratio of the training instance.
    'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
    'colsample_bytree': 0.9,  # Subsample ratio of columns when constructing each tree.
    'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
    'scale_pos_weight':99
}
# metrics = 'auc'
# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': metrics,
#     'learning_rate': .1,
#     'num_leaves': 7,
#     'max_depth': 4,
#     'min_child_samples': 100,
#     'max_bin': 100,
#     'subsample': 0.7,
#     'subsample_freq': 1,
#     'colsample_bytree': 0.7,
#     'min_child_weight': 0,
#     'min_split_gain': 0,
#     'nthread': 4,
#     'verbose': 1,
#     'scale_pos_weight': 99.7
#     #'scale_pos_weight': 400
# }

# %%
target = "is_attributed"
categorical = ['app','os','channel','device','day','hour','minute']
predictors = list(set(train_df.columns)-set([target])-set(['click_time','category','epochtime','ip']))
print(predictors)

print("preparing validation datasets")

xgtrain = lgb.Dataset(train_df[predictors].values,
                      label=y_train,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del train_df
del y_train
gc.collect()

xgvalid = lgb.Dataset(val_df[predictors].values,
                      label=y_val,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del val_df
del y_val
gc.collect()
# Out:
# ['ip_app_os_count', 'channel', 'os', 'ip_count', 'app', 'os_app_channel_count', 'os_device_count', 'ip_day_hour_count', 'ip_day_hour_minute_count', 'ip_device_count', 'device', 'hour', 'day', 'minute', 'app_channel_count', 'next_click', 'ip_app_count']
# preparing validation datasets
# 25

# %%
booster = lgb.train(
     lgb_params, 
     xgtrain,
     valid_sets=[xgvalid],
     valid_names=['valid'],
     evals_result=evals_results, 
     num_boost_round=num_boost_round,
     early_stopping_rounds=early_stopping_rounds,
     verbose_eval=1
)

# n_estimators = model.best_iteration

# print('\nModel Info:')
# print('n_estimators:', n_estimators)
# print(metrics+':', evals_results['valid'][metrics][n_estimators-1])

del xgvalid
del xgtrain
gc.collect()
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	valid's auc: 0.926705
# Training until validation scores don't improve for 30 rounds.
# [2]	valid's auc: 0.951089
# [3]	valid's auc: 0.951701
# [4]	valid's auc: 0.961973
# [5]	valid's auc: 0.962132
# [6]	valid's auc: 0.961898
# [7]	valid's auc: 0.961993
# [8]	valid's auc: 0.962992
# [9]	valid's auc: 0.963207
# [10]	valid's auc: 0.963325
# [11]	valid's auc: 0.963818
# [12]	valid's auc: 0.966438
# [13]	valid's auc: 0.966588
# [14]	valid's auc: 0.967678
# [15]	valid's auc: 0.967607
# [16]	valid's auc: 0.968909
# [17]	valid's auc: 0.969162
# [18]	valid's auc: 0.969314
# [19]	valid's auc: 0.970136
# [20]	valid's auc: 0.970253
# [21]	valid's auc: 0.970536
# [22]	valid's auc: 0.971216
# [23]	valid's auc: 0.971683
# [24]	valid's auc: 0.972431
# [25]	valid's auc: 0.972817
# [26]	valid's auc: 0.973029
# [27]	valid's auc: 0.973426
# [28]	valid's auc: 0.973482
# [29]	valid's auc: 0.974277
# [30]	valid's auc: 0.974586
# [31]	valid's auc: 0.974862
# [32]	valid's auc: 0.975143
# [33]	valid's auc: 0.975523
# [34]	valid's auc: 0.975844
# [35]	valid's auc: 0.976158
# [36]	valid's auc: 0.976539
# [37]	valid's auc: 0.976629
# [38]	valid's auc: 0.976944
# [39]	valid's auc: 0.97714
# [40]	valid's auc: 0.977342
# [41]	valid's auc: 0.977454
# [42]	valid's auc: 0.977574
# [43]	valid's auc: 0.977708
# [44]	valid's auc: 0.977861
# [45]	valid's auc: 0.978028
# [46]	valid's auc: 0.978134
# [47]	valid's auc: 0.978444
# [48]	valid's auc: 0.978566
# [49]	valid's auc: 0.978665
# [50]	valid's auc: 0.978784
# [51]	valid's auc: 0.978911
# [52]	valid's auc: 0.979009
# [53]	valid's auc: 0.979024
# [54]	valid's auc: 0.979052
# [55]	valid's auc: 0.979191
# [56]	valid's auc: 0.979283
# [57]	valid's auc: 0.979317
# [58]	valid's auc: 0.979346
# [59]	valid's auc: 0.979409
# [60]	valid's auc: 0.979494
# [61]	valid's auc: 0.979554
# [62]	valid's auc: 0.979648
# [63]	valid's auc: 0.97972
# [64]	valid's auc: 0.979752
# [65]	valid's auc: 0.979867
# [66]	valid's auc: 0.979885
# [67]	valid's auc: 0.979902
# [68]	valid's auc: 0.979949
# [69]	valid's auc: 0.980017
# [70]	valid's auc: 0.980035
# [71]	valid's auc: 0.980087
# [72]	valid's auc: 0.98008
# [73]	valid's auc: 0.980208
# [74]	valid's auc: 0.980275
# [75]	valid's auc: 0.980317
# [76]	valid's auc: 0.980316
# [77]	valid's auc: 0.980334
# [78]	valid's auc: 0.980373
# [79]	valid's auc: 0.980369
# [80]	valid's auc: 0.980425
# [81]	valid's auc: 0.980454
# [82]	valid's auc: 0.980496
# [83]	valid's auc: 0.980539
# [84]	valid's auc: 0.980563
# [85]	valid's auc: 0.980609
# [86]	valid's auc: 0.980624
# [87]	valid's auc: 0.980648
# [88]	valid's auc: 0.98069
# [89]	valid's auc: 0.980707
# [90]	valid's auc: 0.980713
# [91]	valid's auc: 0.980715
# [92]	valid's auc: 0.980706
# [93]	valid's auc: 0.980717
# [94]	valid's auc: 0.980792
# [95]	valid's auc: 0.980813
# [96]	valid's auc: 0.980838
# [97]	valid's auc: 0.980854
# [98]	valid's auc: 0.980888
# [99]	valid's auc: 0.980911
# [100]	valid's auc: 0.980942
# [101]	valid's auc: 0.980975
# [102]	valid's auc: 0.980987
# [103]	valid's auc: 0.981031
# [104]	valid's auc: 0.981038
# [105]	valid's auc: 0.981035
# [106]	valid's auc: 0.981071
# [107]	valid's auc: 0.981104
# [108]	valid's auc: 0.981108
# [109]	valid's auc: 0.981116
# [110]	valid's auc: 0.981151
# [111]	valid's auc: 0.981148
# [112]	valid's auc: 0.981143
# [113]	valid's auc: 0.981149
# [114]	valid's auc: 0.981177
# [115]	valid's auc: 0.981207
# [116]	valid's auc: 0.981228
# [117]	valid's auc: 0.981256
# [118]	valid's auc: 0.981278
# [119]	valid's auc: 0.981293
# [120]	valid's auc: 0.981306
# [121]	valid's auc: 0.981328
# [122]	valid's auc: 0.981318
# [123]	valid's auc: 0.981323
# [124]	valid's auc: 0.981335
# [125]	valid's auc: 0.981353
# [126]	valid's auc: 0.981375
# [127]	valid's auc: 0.981387
# [128]	valid's auc: 0.981395
# [129]	valid's auc: 0.981415
# [130]	valid's auc: 0.981414
# [131]	valid's auc: 0.981434
# [132]	valid's auc: 0.981452
# [133]	valid's auc: 0.981466
# [134]	valid's auc: 0.981469
# [135]	valid's auc: 0.981471
# [136]	valid's auc: 0.981485
# [137]	valid's auc: 0.981476
# [138]	valid's auc: 0.981463
# [139]	valid's auc: 0.981477
# [140]	valid's auc: 0.981488
# [141]	valid's auc: 0.981489
# [142]	valid's auc: 0.98149
# [143]	valid's auc: 0.981513
# [144]	valid's auc: 0.981517
# [145]	valid's auc: 0.981512
# [146]	valid's auc: 0.981509
# [147]	valid's auc: 0.981515
# [148]	valid's auc: 0.981516
# [149]	valid's auc: 0.981531
# [150]	valid's auc: 0.981544
# [151]	valid's auc: 0.981545
# [152]	valid's auc: 0.981533
# [153]	valid's auc: 0.981543
# [154]	valid's auc: 0.981544
# [155]	valid's auc: 0.981559
# [156]	valid's auc: 0.981575
# [157]	valid's auc: 0.981571
# [158]	valid's auc: 0.981583
# [159]	valid's auc: 0.981592
# [160]	valid's auc: 0.981595
# [161]	valid's auc: 0.9816
# [162]	valid's auc: 0.981599
# [163]	valid's auc: 0.981594
# [164]	valid's auc: 0.981614
# [165]	valid's auc: 0.981619
# [166]	valid's auc: 0.981612
# [167]	valid's auc: 0.98162
# [168]	valid's auc: 0.981624
# [169]	valid's auc: 0.98163
# [170]	valid's auc: 0.981626
# [171]	valid's auc: 0.981615
# [172]	valid's auc: 0.981617
# [173]	valid's auc: 0.981616
# [174]	valid's auc: 0.981612
# [175]	valid's auc: 0.981635
# [176]	valid's auc: 0.981627
# [177]	valid's auc: 0.981606
# [178]	valid's auc: 0.981599
# [179]	valid's auc: 0.981611
# [180]	valid's auc: 0.981619
# [181]	valid's auc: 0.981623
# [182]	valid's auc: 0.981623
# [183]	valid's auc: 0.981635
# [184]	valid's auc: 0.981631
# [185]	valid's auc: 0.981635
# [186]	valid's auc: 0.981655
# [187]	valid's auc: 0.98165
# [188]	valid's auc: 0.981653
# [189]	valid's auc: 0.981644
# [190]	valid's auc: 0.981638
# [191]	valid's auc: 0.981629
# [192]	valid's auc: 0.981638
# [193]	valid's auc: 0.981641
# [194]	valid's auc: 0.98164
# [195]	valid's auc: 0.981652
# [196]	valid's auc: 0.981663
# [197]	valid's auc: 0.98166
# [198]	valid's auc: 0.981666
# [199]	valid's auc: 0.981659
# [200]	valid's auc: 0.981658
# [201]	valid's auc: 0.981656
# [202]	valid's auc: 0.981657
# [203]	valid's auc: 0.981657
# [204]	valid's auc: 0.981657
# [205]	valid's auc: 0.981668
# [206]	valid's auc: 0.981675
# [207]	valid's auc: 0.981677
# [208]	valid's auc: 0.981676
# [209]	valid's auc: 0.981664
# [210]	valid's auc: 0.981674
# [211]	valid's auc: 0.981671
# [212]	valid's auc: 0.981674
# [213]	valid's auc: 0.981671
# [214]	valid's auc: 0.981667
# [215]	valid's auc: 0.981663
# [216]	valid's auc: 0.981667
# [217]	valid's auc: 0.98167
# [218]	valid's auc: 0.98168
# [219]	valid's auc: 0.981676
# [220]	valid's auc: 0.981677
# [221]	valid's auc: 0.981667
# [222]	valid's auc: 0.981664
# [223]	valid's auc: 0.981672
# [224]	valid's auc: 0.98168
# [225]	valid's auc: 0.981675
# [226]	valid's auc: 0.981674
# [227]	valid's auc: 0.981673
# [228]	valid's auc: 0.981665
# [229]	valid's auc: 0.981674
# [230]	valid's auc: 0.981672
# [231]	valid's auc: 0.981667
# [232]	valid's auc: 0.981665
# [233]	valid's auc: 0.981652
# [234]	valid's auc: 0.981663
# [235]	valid's auc: 0.981657
# [236]	valid's auc: 0.981659
# [237]	valid's auc: 0.981662
# [238]	valid's auc: 0.981665
# [239]	valid's auc: 0.981666
# [240]	valid's auc: 0.981678
# [241]	valid's auc: 0.981672
# [242]	valid's auc: 0.981669
# [243]	valid's auc: 0.981672
# [244]	valid's auc: 0.981685
# [245]	valid's auc: 0.98168
# [246]	valid's auc: 0.981676
# [247]	valid's auc: 0.98168
# [248]	valid's auc: 0.981675
# [249]	valid's auc: 0.981679
# [250]	valid's auc: 0.981677
# Did not meet early stopping. Best iteration is:
# [244]	valid's auc: 0.981685
# 32

# %%
import matplotlib.pyplot as plt
ax = lgb.plot_importance(booster, max_num_features=100)
# plt.savefig('04303-1imp.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
preditions=booster.predict(test_df[predictors].values)

# %%
sub['is_attributed']  = preditions

sub.to_csv('04303-1sub.csv', float_format='%.8f', index=False)
