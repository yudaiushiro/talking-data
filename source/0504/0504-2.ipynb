# %% [markdown]
# train120m-180m, train:valid 90:10(shuffle), add more nextclick
# 1. num_boost_round = 250, early_stopping_rounds = 30
# 2. num_boost_round = 500, early_stopping_rounds = 50

# %%
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import gc
from contextlib import contextmanager
import matplotlib.pyplot as plt

# %%
@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f'[{name}] done in {time.time() - t0:.0f} s')
    
def do_next_Click(df,agg_suffix='nextClick', agg_type='float32'):
    with timer("Adding next click times"):
    
        print(f">> \nExtracting {agg_suffix} time calculation features...\n")

        GROUP_BY_NEXT_CLICKS = [

        # V1
        # {'groupby': ['ip']},
        # {'groupby': ['ip', 'app']},
        # {'groupby': ['ip', 'channel']},
        # {'groupby': ['ip', 'os']},

        # V3
        {'groupby': ['ip', 'app', 'device', 'os', 'channel']},
        {'groupby': ['ip', 'os', 'device']},
        {'groupby': ['ip', 'os', 'device', 'app']},
    #     {'groupby': ['device']},
    #     {'groupby': ['device', 'channel']},     
        {'groupby': ['app', 'device', 'channel']},
#         {'groupby': ['device', 'hour']}
        ]

        # Calculate the time to next click for each group
        for spec in GROUP_BY_NEXT_CLICKS:

           # Name of new feature
            new_feature = '{}_{}'.format('_'.join(spec['groupby']),agg_suffix)    

            # Unique list of features to select
            all_features = spec['groupby'] + ['click_time']

            # Run calculation
            print(f">> Grouping by {spec['groupby']}, and saving time to {agg_suffix} in: {new_feature}")
            df[new_feature] = (df[all_features].groupby(spec[
                'groupby']).click_time.shift(-1) - df.click_time).dt.seconds.astype(agg_type)

#             predictors.append(new_feature)
            gc.collect()
        return (df)

def df_add_counts(df, cols):
    arr_slice = df[cols].values
    unq, unqtags, counts = np.unique(np.ravel_multi_index(arr_slice.T, arr_slice.max(axis=0) + 1),
                                     return_inverse=True, return_counts=True)
    df["_".join(cols)+'_count'] = counts[unqtags]
    gc.collect()
    
def make_count_features(df):
    with timer("add count features"):
        df['click_time']= pd.to_datetime(df['click_time'])
        dt= df['click_time'].dt
#         df['day'] = dt.day.astype('uint8')
        df['hour'] = dt.hour.astype('uint8')
#         df['minute'] = dt.minute.astype('uint8')
#         df['second'] = dt.second.astype('uint8')#secondを追加

        del(dt)
        
        df_add_counts(df, ['ip'])
#         df_add_counts(df, ['ip','day','hour','minute'])
        df_add_counts(df, ['os','device'])
        df_add_counts(df, ['os','app','channel'])
        
        df_add_counts(df, ['ip', 'hour'])
        df_add_counts(df, ['ip', 'app'])
        df_add_counts(df, ['ip', 'app', 'os'])
        df_add_counts(df, ['ip', 'device'])
        df_add_counts(df, ['app', 'channel'])

def do_countuniq( df, group_cols, counted, agg_type='uint32', show_max=False, show_agg=True ):
    agg_name= '{}_by_{}_countuniq'.format(('_'.join(group_cols)),(counted))  
    if show_agg:
        print( "\nCounting unqiue ", counted, " by ", group_cols ,  '... and saved in', agg_name )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].nunique().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
#     predictors.append(agg_name)
#     print('predictors',predictors)
    gc.collect()
    return( df )

def make_countuniq_features(df):
    with timer("add countuniq features"):
        df = do_countuniq( df, ['ip'], 'channel' ); gc.collect()
        df = do_countuniq( df, ['ip', 'device', 'os'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip'], 'hour' ); gc.collect()
        df = do_countuniq( df, ['ip'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip', 'app'], 'os'); gc.collect()
        df = do_countuniq( df, ['ip'], 'device'); gc.collect()
        df = do_countuniq( df, ['app'], 'channel'); gc.collect()
        return(df)

# def make_next_click_feature(df):
#     with timer("Adding next click times"):
#         D= 2**26
#         df['category'] = (df['ip'].astype(str) + "_" + df['app'].astype(str) + "_" + df['device'].astype(str) \
#                          + "_" + df['os'].astype(str)).apply(hash) % D
#         click_buffer= np.full(D, 3000000000, dtype=np.uint32)
#         df['epochtime']= df['click_time'].astype(np.int64) // 10 ** 9
#         next_clicks= []
#         for category, time in zip(reversed(df['category'].values), reversed(df['epochtime'].values)):
#             next_clicks.append(click_buffer[category]-time)
#             click_buffer[category]= time
#         del(click_buffer)
#         df['next_click']= list(reversed(next_clicks))
#         gc.collect()
        
path = '~/talkingdata/input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

columns = ['ip','app','device','os', 'channel', 'click_time', 'is_attributed']

# %%
with timer("load training data"):
    train_df = pd.read_csv(path+"train.csv",skiprows=range(1,122071518), usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)

with timer("load test data"):
    testsup_df = pd.read_csv(path+"test_supplement.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load training data] done in 120 s
# [load test data] done in 43 s

# %%
num_train = train_df.shape[0]

y = train_df.is_attributed.values
gc.collect()

# sub = pd.DataFrame()
# sub['click_id'] = test_df.click_id.values

common_column = ['ip','app','device','os','channel','click_time']
concat_df = pd.concat([train_df[common_column],testsup_df[common_column]])

del train_df, testsup_df
gc.collect()
# Out:
# 64

# %%
# from multiprocessing import Pool
# import multiprocessing as multi

# p = Pool(multi.cpu_count())
# p.map(make_count_features, concat_df)
# p.close()

# %%
make_count_features(concat_df)
# Out:
# [add count features] done in 456 s

# %%
concat_df = make_countuniq_features(concat_df)

gc.collect()
# Out:
# Counting unqiue  channel  by  ['ip'] ... and saved in ip_by_channel_countuniq
#
# Counting unqiue  app  by  ['ip', 'device', 'os'] ... and saved in ip_device_os_by_app_countuniq
#
# Counting unqiue  hour  by  ['ip'] ... and saved in ip_by_hour_countuniq
#
# Counting unqiue  app  by  ['ip'] ... and saved in ip_by_app_countuniq
#
# Counting unqiue  os  by  ['ip', 'app'] ... and saved in ip_app_by_os_countuniq
#
# Counting unqiue  device  by  ['ip'] ... and saved in ip_by_device_countuniq
#
# Counting unqiue  channel  by  ['app'] ... and saved in app_by_channel_countuniq
# [add countuniq features] done in 1032 s
# 41

# %%
concat_df = do_next_Click(concat_df)
gc.collect()
# Out:
# >>
# Extracting nextClick time calculation features...
#
# >> Grouping by ['ip', 'os', 'device', 'app'], and saving time to nextClick in: ip_os_device_app_nextClick
# >> Grouping by ['app', 'device', 'channel'], and saving time to nextClick in: app_device_channel_nextClick
# [Adding next click times] done in 1464 s
# 0

# %%
concat_df.head()
# Out:
#        ip  app  device   os  channel          click_time  hour  ip_count  \
# 0   62766    7    3543  748      101 2017-11-08 16:00:00    16      3103
# 1  108229   15       1   19      245 2017-11-08 16:00:00    16      7399
# 2   73487   12       2   22      326 2017-11-08 16:00:00    16    486915
# 3  238206   14       1   19      379 2017-11-08 16:00:00    16         1
# 4   27482   26       1   32      121 2017-11-08 16:00:00    16      3958
#
#    os_device_count  os_app_channel_count              ...               \
# 0                1                     1              ...
# 1         27561927                289727              ...
# 2           158918                 14319              ...
# 3         27561927                319932              ...
# 4          1006744                  9873              ...
#
#    ip_device_os_by_app_countuniq  ip_by_hour_countuniq  ip_by_app_countuniq  \
# 0                              1                    24                   43
# 1                             32                    24                   46
# 2                             28                    24                  173
# 3                              1                     1                    1
# 4                             17                    24                   47
#
#    ip_app_by_os_countuniq  ip_by_device_countuniq  app_by_channel_countuniq  \
# 0                      10                       7                         3
# 1                      44                      12                        27
# 2                     125                     148                        32
# 3                       1                       1                        38
# 4                      17                      12                         5
#
#    ip_app_device_os_channel_nextClick  ip_os_device_nextClick  \
# 0                                 NaN                     NaN
# 1                               371.0                    58.0
# 2                               181.0                    15.0
# 3                                 NaN                     NaN
# 4                             32379.0                    16.0
#
#    ip_os_device_app_nextClick  app_device_channel_nextClick
# 0                         NaN                           NaN
# 1                       200.0                           1.0
# 2                       181.0                           1.0
# 3                         NaN                           1.0
# 4                       927.0                           1.0
#
# [5 rows x 26 columns]

# %%
train_df = concat_df.iloc[:num_train]
testsup_df = concat_df.iloc[num_train:]

del concat_df
gc.collect()
# Out:
# 60

# %%
import sys

print("{}{: >25}{}{: >10}{}".format('|','Variable Name','|','Memory','|'))
print(" ------------------------------------ ")
for var_name in dir():
    if not var_name.startswith("_"):
        print("{}{: >25}{}{: >10}{}".format('|',var_name,'|',sys.getsizeof(eval(var_name)),'|'))
gc.collect()
# Out:
# |            Variable Name|    Memory|
#  ------------------------------------
# |                       In|       432|
# |                      Out|       648|
# |                 all_cols|       120|
# |                       ax|        56|
# |              categorical|       104|
# |                  columns|       120|
# |            common_column|       112|
# |           contextmanager|       136|
# |            df_add_counts|       136|
# |             do_countuniq|       136|
# |            do_next_Click|       136|
# |                   dtypes|       368|
# |    early_stopping_rounds|        28|
# |            evals_results|       240|
# |                     exit|        56|
# |                        f|       176|
# |                       gc|        80|
# |              get_ipython|        64|
# |                join_cols|       112|
# |                      lgb|        80|
# |               lgb_params|       648|
# |      make_count_features|       136|
# |  make_countuniq_features|       136|
# |                  metrics|        52|
# |             n_estimators|        28|
# |                       np|        80|
# |          num_boost_round|        28|
# |                num_train|        28|
# |                     path|        69|
# |                       pd|        80|
# |                   pickle|        80|
# |                      plt|        80|
# |               predictors|       328|
# |                     quit|        56|
# |                      sys|        80|
# |                   target|       118|
# |                  test_df| 751618784|
# |               testsup_df|8342938249|
# |                     time|        80|
# |                    timer|       136|
# |         train_test_split|       136|
# |                 var_name|        57|
# |                  xgtrain|        56|
# |                  xgvalid|        56|
# 267

# %%
import pickle
with open('train_after.csv.pkl','wb') as f:
  pickle.dump(train_df, f, protocol=4)

with open('testsup_after.csv.pkl','wb') as f:
  pickle.dump(testsup_df, f, protocol=4)

# with open('test_after.csv.pkl','wb') as f:
#   pickle.dump(test_df, f, protocol=2)

# %%
train_df = pd.DataFrame()
with open('train_after.csv.pkl','rb') as f:
  train_df = pickle.load(f)

# %%
with timer("load training data"):
    train = pd.read_csv(path+"train.csv",skiprows=range(1,122071518), usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)
y = train.is_attributed.values
del train
# Out:
# [load training data] done in 120 s

# %%
x_train, x_val, y_train, y_val = train_test_split(train_df, y, train_size=0.9, random_state=0)

del train_df, y
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
evals_results = {}
# num_boost_round = 250
# early_stopping_rounds = 30
num_boost_round = 500
early_stopping_rounds = 50

lgb_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'subsample_for_bin': 200000,  # Number of samples for constructing bin
    'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
    'reg_alpha': 0,  # L1 regularization term on weights
    'reg_lambda': 0,  # L2 regularization term on weights
    'nthread': 10,
    'verbose': 0,
    'metric':'auc',     
 
    'learning_rate': 0.15,
    'num_leaves': 7,  # 2^max_depth - 1
    'max_depth': 3,  # -1 means no limit
    'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
    'max_bin': 100,  # Number of bucketed bin for feature values
    'subsample': 0.7,  # Subsample ratio of the training instance.
    'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
    'colsample_bytree': 0.9,  # Subsample ratio of columns when constructing each tree.
    'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
    'scale_pos_weight':99
}

# # matsuda Hyperparameters
# min_data_in_leaf = 50
# max_bin = 127
# bagging_fraction = 0.7
# bagging_freq = 1 
# feature_fraction = 0.9
# bin_construct_sample_cnt = 100000
# min_hessian = 0 
# scale_pos_weight = 200
# max_depth = -1

# params = {
#    ‘boosting_type’: ‘gbdt’,
#    ‘objective’: ‘binary’,
#    ‘min_split_gain’: 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
#    ‘nthread’: 8,
#    ‘verbose’: 0,
#    ‘metric’: ‘auc’,
#    ‘learning_rate’: 0.10,
#    ‘max_depth’: max_depth,  # -1 means no limit
#    ‘num_leaves’: 31,  # 2^max_depth - 1
#    ‘min_child_samples’: min_data_in_leaf,  # Minimum number of data need in a child(min_data_in_leaf)
#    ‘max_bin’: max_bin,  # Number of bucketed bin for feature values
#    ‘bin_construct_sample_cnt’: bin_construct_sample_cnt,
#    # ‘subsample_for_bin’: 20000,  # Number of samples for constructing bin
#    ‘bagging_fraction’: bagging_fraction,  # subsample
#    ‘bagging_freq’: bagging_freq,  # subsample_freq
#    ‘feature_fraction’: feature_fraction,  # colsample_bytree
#    ‘min_sum_hessian_in_leaf’: min_hessian,  # min_child_weight
#    ‘scale_pos_weight’: scale_pos_weight
# }


# metrics = 'auc'
# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': metrics,
#     'learning_rate': .1,
#     'num_leaves': 7,
#     'max_depth': 4,
#     'min_child_samples': 100,
#     'max_bin': 100,
#     'subsample': 0.7,
#     'subsample_freq': 1,
#     'colsample_bytree': 0.7,
#     'min_child_weight': 0,
#     'min_split_gain': 0,
#     'nthread': 4,
#     'verbose': 1,
#     'scale_pos_weight': 99.7
#     #'scale_pos_weight': 400
# }

# %%
target = "is_attributed"
categorical = ['app','os','channel','device','hour']
predictors = list(set(x_train.columns)-set([target])-set(['click_time','ip']))
print(predictors)

print("preparing validation datasets")

xgtrain = lgb.Dataset(x_train[predictors].values,
                      label=y_train,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_train
del y_train
gc.collect()

xgvalid = lgb.Dataset(x_val[predictors].values,
                      label=y_val,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_val
del y_val
gc.collect()
# Out:
# ['ip_by_app_countuniq', 'device', 'app_by_channel_countuniq', 'ip_by_channel_countuniq', 'ip_app_device_os_channel_nextClick', 'ip_count', 'channel', 'ip_app_os_count', 'os_app_channel_count', 'app', 'hour', 'ip_by_hour_countuniq', 'ip_by_device_countuniq', 'ip_device_count', 'ip_os_device_nextClick', 'os_device_count', 'ip_hour_count', 'app_device_channel_nextClick', 'ip_os_device_app_nextClick', 'os', 'ip_app_by_os_countuniq', 'ip_device_os_by_app_countuniq', 'app_channel_count', 'ip_app_count']
# preparing validation datasets
# 34

# %%
# gc.collect()
# del booster
booster = lgb.train(
     lgb_params, 
     xgtrain,
     valid_sets=[xgvalid],
     valid_names=['valid'],
     evals_result=evals_results, 
     num_boost_round=num_boost_round,
     early_stopping_rounds=early_stopping_rounds,
     verbose_eval=1
)

del xgvalid
del xgtrain
gc.collect()
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	valid's auc: 0.942804
# Training until validation scores don't improve for 50 rounds.
# [2]	valid's auc: 0.949993
# [3]	valid's auc: 0.952755
# [4]	valid's auc: 0.95268
# [5]	valid's auc: 0.952806
# [6]	valid's auc: 0.96409
# [7]	valid's auc: 0.964203
# [8]	valid's auc: 0.964276
# [9]	valid's auc: 0.964508
# [10]	valid's auc: 0.964825
# [11]	valid's auc: 0.965703
# [12]	valid's auc: 0.966857
# [13]	valid's auc: 0.967109
# [14]	valid's auc: 0.968367
# [15]	valid's auc: 0.96865
# [16]	valid's auc: 0.970188
# [17]	valid's auc: 0.970306
# [18]	valid's auc: 0.971454
# [19]	valid's auc: 0.971271
# [20]	valid's auc: 0.971905
# [21]	valid's auc: 0.972191
# [22]	valid's auc: 0.972441
# [23]	valid's auc: 0.973297
# [24]	valid's auc: 0.974305
# [25]	valid's auc: 0.974979
# [26]	valid's auc: 0.975065
# [27]	valid's auc: 0.975419
# [28]	valid's auc: 0.975838
# [29]	valid's auc: 0.976068
# [30]	valid's auc: 0.976187
# [31]	valid's auc: 0.976224
# [32]	valid's auc: 0.976625
# [33]	valid's auc: 0.976831
# [34]	valid's auc: 0.97705
# [35]	valid's auc: 0.977438
# [36]	valid's auc: 0.977863
# [37]	valid's auc: 0.978209
# [38]	valid's auc: 0.978288
# [39]	valid's auc: 0.978311
# [40]	valid's auc: 0.978547
# [41]	valid's auc: 0.978744
# [42]	valid's auc: 0.97893
# [43]	valid's auc: 0.978981
# [44]	valid's auc: 0.979177
# [45]	valid's auc: 0.979237
# [46]	valid's auc: 0.979362
# [47]	valid's auc: 0.979473
# [48]	valid's auc: 0.979519
# [49]	valid's auc: 0.979715
# [50]	valid's auc: 0.979796
# [51]	valid's auc: 0.979869
# [52]	valid's auc: 0.979951
# [53]	valid's auc: 0.980055
# [54]	valid's auc: 0.980135
# [55]	valid's auc: 0.980188
# [56]	valid's auc: 0.980286
# [57]	valid's auc: 0.980356
# [58]	valid's auc: 0.9804
# [59]	valid's auc: 0.980442
# [60]	valid's auc: 0.98049
# [61]	valid's auc: 0.980604
# [62]	valid's auc: 0.980714
# [63]	valid's auc: 0.980713
# [64]	valid's auc: 0.980763
# [65]	valid's auc: 0.980799
# [66]	valid's auc: 0.980845
# [67]	valid's auc: 0.980871
# [68]	valid's auc: 0.98096
# [69]	valid's auc: 0.981
# [70]	valid's auc: 0.981046
# [71]	valid's auc: 0.981071
# [72]	valid's auc: 0.981125
# [73]	valid's auc: 0.981148
# [74]	valid's auc: 0.981216
# [75]	valid's auc: 0.981236
# [76]	valid's auc: 0.981283
# [77]	valid's auc: 0.981294
# [78]	valid's auc: 0.981321
# [79]	valid's auc: 0.981358
# [80]	valid's auc: 0.981392
# [81]	valid's auc: 0.981419
# [82]	valid's auc: 0.981433
# [83]	valid's auc: 0.981446
# [84]	valid's auc: 0.98148
# [85]	valid's auc: 0.98151
# [86]	valid's auc: 0.981512
# [87]	valid's auc: 0.981545
# [88]	valid's auc: 0.981585
# [89]	valid's auc: 0.981603
# [90]	valid's auc: 0.981633
# [91]	valid's auc: 0.981659
# [92]	valid's auc: 0.981695
# [93]	valid's auc: 0.981715
# [94]	valid's auc: 0.981751
# [95]	valid's auc: 0.981785
# [96]	valid's auc: 0.981816
# [97]	valid's auc: 0.981834
# [98]	valid's auc: 0.98185
# [99]	valid's auc: 0.981888
# [100]	valid's auc: 0.981892
# [101]	valid's auc: 0.981911
# [102]	valid's auc: 0.981929
# [103]	valid's auc: 0.981954
# [104]	valid's auc: 0.981978
# [105]	valid's auc: 0.981993
# [106]	valid's auc: 0.982014
# [107]	valid's auc: 0.982043
# [108]	valid's auc: 0.982055
# [109]	valid's auc: 0.982084
# [110]	valid's auc: 0.982137
# [111]	valid's auc: 0.982137
# [112]	valid's auc: 0.982197
# [113]	valid's auc: 0.982209
# [114]	valid's auc: 0.98224
# [115]	valid's auc: 0.982248
# [116]	valid's auc: 0.982263
# [117]	valid's auc: 0.982279
# [118]	valid's auc: 0.982286
# [119]	valid's auc: 0.982307
# [120]	valid's auc: 0.982324
# [121]	valid's auc: 0.982329
# [122]	valid's auc: 0.982346
# [123]	valid's auc: 0.982357
# [124]	valid's auc: 0.98239
# [125]	valid's auc: 0.98242
# [126]	valid's auc: 0.982426
# [127]	valid's auc: 0.982429
# [128]	valid's auc: 0.982447
# [129]	valid's auc: 0.982474
# [130]	valid's auc: 0.982476
# [131]	valid's auc: 0.982496
# [132]	valid's auc: 0.982505
# [133]	valid's auc: 0.982513
# [134]	valid's auc: 0.982573
# [135]	valid's auc: 0.982596
# [136]	valid's auc: 0.982601
# [137]	valid's auc: 0.982607
# [138]	valid's auc: 0.982638
# [139]	valid's auc: 0.982643
# [140]	valid's auc: 0.982654
# [141]	valid's auc: 0.982668
# [142]	valid's auc: 0.982679
# [143]	valid's auc: 0.982693
# [144]	valid's auc: 0.982712
# [145]	valid's auc: 0.982722
# [146]	valid's auc: 0.982733
# [147]	valid's auc: 0.982725
# [148]	valid's auc: 0.982737
# [149]	valid's auc: 0.982758
# [150]	valid's auc: 0.982772
# [151]	valid's auc: 0.982789
# [152]	valid's auc: 0.982805
# [153]	valid's auc: 0.982813
# [154]	valid's auc: 0.982829
# [155]	valid's auc: 0.982863
# [156]	valid's auc: 0.982873
# [157]	valid's auc: 0.982891
# [158]	valid's auc: 0.9829
# [159]	valid's auc: 0.982906
# [160]	valid's auc: 0.982931
# [161]	valid's auc: 0.982943
# [162]	valid's auc: 0.98295
# [163]	valid's auc: 0.982953
# [164]	valid's auc: 0.982957
# [165]	valid's auc: 0.982962
# [166]	valid's auc: 0.982976
# [167]	valid's auc: 0.983
# [168]	valid's auc: 0.983006
# [169]	valid's auc: 0.983009
# [170]	valid's auc: 0.983026
# [171]	valid's auc: 0.983026
# [172]	valid's auc: 0.983028
# [173]	valid's auc: 0.98303
# [174]	valid's auc: 0.983042
# [175]	valid's auc: 0.983054
# [176]	valid's auc: 0.983067
# [177]	valid's auc: 0.983076
# [178]	valid's auc: 0.983094
# [179]	valid's auc: 0.983106
# [180]	valid's auc: 0.983109
# [181]	valid's auc: 0.983099
# [182]	valid's auc: 0.983114
# [183]	valid's auc: 0.983123
# [184]	valid's auc: 0.983132
# [185]	valid's auc: 0.983144
# [186]	valid's auc: 0.983152
# [187]	valid's auc: 0.983162
# [188]	valid's auc: 0.983166
# [189]	valid's auc: 0.983172
# [190]	valid's auc: 0.983178
# [191]	valid's auc: 0.98318
# [192]	valid's auc: 0.983185
# [193]	valid's auc: 0.983187
# [194]	valid's auc: 0.983181
# [195]	valid's auc: 0.983182
# [196]	valid's auc: 0.983199
# [197]	valid's auc: 0.983199
# [198]	valid's auc: 0.983206
# [199]	valid's auc: 0.983204
# [200]	valid's auc: 0.983206
# [201]	valid's auc: 0.983217
# [202]	valid's auc: 0.983211
# [203]	valid's auc: 0.983216
# [204]	valid's auc: 0.983222
# [205]	valid's auc: 0.983228
# [206]	valid's auc: 0.983244
# [207]	valid's auc: 0.983262
# [208]	valid's auc: 0.983261
# [209]	valid's auc: 0.983268
# [210]	valid's auc: 0.983268
# [211]	valid's auc: 0.983272
# [212]	valid's auc: 0.983279
# [213]	valid's auc: 0.983281
# [214]	valid's auc: 0.983287
# [215]	valid's auc: 0.983291
# [216]	valid's auc: 0.983291
# [217]	valid's auc: 0.983301
# [218]	valid's auc: 0.983303
# [219]	valid's auc: 0.983302
# [220]	valid's auc: 0.983302
# [221]	valid's auc: 0.983306
# [222]	valid's auc: 0.983301
# [223]	valid's auc: 0.983306
# [224]	valid's auc: 0.98331
# [225]	valid's auc: 0.983312
# [226]	valid's auc: 0.983316
# [227]	valid's auc: 0.983339
# [228]	valid's auc: 0.983339
# [229]	valid's auc: 0.983343
# [230]	valid's auc: 0.983355
# [231]	valid's auc: 0.983363
# [232]	valid's auc: 0.983367
# [233]	valid's auc: 0.98336
# [234]	valid's auc: 0.983368
# [235]	valid's auc: 0.983377
# [236]	valid's auc: 0.983384
# [237]	valid's auc: 0.983391
# [238]	valid's auc: 0.983398
# [239]	valid's auc: 0.9834
# [240]	valid's auc: 0.983398
# [241]	valid's auc: 0.983402
# [242]	valid's auc: 0.983424
# [243]	valid's auc: 0.98343
# [244]	valid's auc: 0.983434
# [245]	valid's auc: 0.983433
# [246]	valid's auc: 0.983434
# [247]	valid's auc: 0.98344
# [248]	valid's auc: 0.983451
# [249]	valid's auc: 0.983456
# [250]	valid's auc: 0.983464
# [251]	valid's auc: 0.983474
# [252]	valid's auc: 0.983479
# [253]	valid's auc: 0.98348
# [254]	valid's auc: 0.983477
# [255]	valid's auc: 0.983481
# [256]	valid's auc: 0.983481
# [257]	valid's auc: 0.983478
# [258]	valid's auc: 0.983479
# [259]	valid's auc: 0.983483
# [260]	valid's auc: 0.98348
# [261]	valid's auc: 0.98348
# [262]	valid's auc: 0.983476
# [263]	valid's auc: 0.983483
# [264]	valid's auc: 0.983488
# [265]	valid's auc: 0.983495
# [266]	valid's auc: 0.983494
# [267]	valid's auc: 0.983499
# [268]	valid's auc: 0.983498
# [269]	valid's auc: 0.983505
# [270]	valid's auc: 0.983508
# [271]	valid's auc: 0.983511
# [272]	valid's auc: 0.983515
# [273]	valid's auc: 0.983515
# [274]	valid's auc: 0.983517
# [275]	valid's auc: 0.983524
# [276]	valid's auc: 0.983523
# [277]	valid's auc: 0.983524
# [278]	valid's auc: 0.983531
# [279]	valid's auc: 0.983539
# [280]	valid's auc: 0.983537
# [281]	valid's auc: 0.983542
# [282]	valid's auc: 0.983548
# [283]	valid's auc: 0.983547
# [284]	valid's auc: 0.983547
# [285]	valid's auc: 0.983549
# [286]	valid's auc: 0.983546
# [287]	valid's auc: 0.983544
# [288]	valid's auc: 0.983544
# [289]	valid's auc: 0.983542
# [290]	valid's auc: 0.983545
# [291]	valid's auc: 0.983547
# [292]	valid's auc: 0.983546
# [293]	valid's auc: 0.983546
# [294]	valid's auc: 0.983547
# [295]	valid's auc: 0.983548
# [296]	valid's auc: 0.983549
# [297]	valid's auc: 0.983544
# [298]	valid's auc: 0.98355
# [299]	valid's auc: 0.983549
# [300]	valid's auc: 0.983559
# [301]	valid's auc: 0.983565
# [302]	valid's auc: 0.983561
# [303]	valid's auc: 0.983565
# [304]	valid's auc: 0.98357
# [305]	valid's auc: 0.983573
# [306]	valid's auc: 0.983576
# [307]	valid's auc: 0.983579
# [308]	valid's auc: 0.983579
# [309]	valid's auc: 0.983575
# [310]	valid's auc: 0.983575
# [311]	valid's auc: 0.983573
# [312]	valid's auc: 0.983567
# [313]	valid's auc: 0.983572
# [314]	valid's auc: 0.98358
# [315]	valid's auc: 0.983573
# [316]	valid's auc: 0.983579
# [317]	valid's auc: 0.983574
# [318]	valid's auc: 0.983579
# [319]	valid's auc: 0.983578
# [320]	valid's auc: 0.983581
# [321]	valid's auc: 0.983581
# [322]	valid's auc: 0.983581
# [323]	valid's auc: 0.983584
# [324]	valid's auc: 0.983583
# [325]	valid's auc: 0.983577
# [326]	valid's auc: 0.983577
# [327]	valid's auc: 0.983578
# [328]	valid's auc: 0.983575
# [329]	valid's auc: 0.983576
# [330]	valid's auc: 0.983576
# [331]	valid's auc: 0.983578
# [332]	valid's auc: 0.983581
# [333]	valid's auc: 0.98358
# [334]	valid's auc: 0.983581
# [335]	valid's auc: 0.983582
# [336]	valid's auc: 0.983575
# [337]	valid's auc: 0.98358
# [338]	valid's auc: 0.983583
# [339]	valid's auc: 0.983584
# [340]	valid's auc: 0.98359
# [341]	valid's auc: 0.983598
# [342]	valid's auc: 0.9836
# [343]	valid's auc: 0.983597
# [344]	valid's auc: 0.983594
# [345]	valid's auc: 0.983596
# [346]	valid's auc: 0.983594
# [347]	valid's auc: 0.98359
# [348]	valid's auc: 0.983592
# [349]	valid's auc: 0.983587
# [350]	valid's auc: 0.983589
# [351]	valid's auc: 0.983595
# [352]	valid's auc: 0.983601
# [353]	valid's auc: 0.983606
# [354]	valid's auc: 0.983608
# [355]	valid's auc: 0.983609
# [356]	valid's auc: 0.983612
# [357]	valid's auc: 0.983611
# [358]	valid's auc: 0.983616
# [359]	valid's auc: 0.983617
# [360]	valid's auc: 0.983613
# [361]	valid's auc: 0.983616
# [362]	valid's auc: 0.983622
# [363]	valid's auc: 0.983624
# [364]	valid's auc: 0.983631
# [365]	valid's auc: 0.983637
# [366]	valid's auc: 0.983639
# [367]	valid's auc: 0.983632
# [368]	valid's auc: 0.98363
# [369]	valid's auc: 0.98363
# [370]	valid's auc: 0.983629
# [371]	valid's auc: 0.983635
# [372]	valid's auc: 0.983636
# [373]	valid's auc: 0.983641
# [374]	valid's auc: 0.983641
# [375]	valid's auc: 0.983644
# [376]	valid's auc: 0.983649
# [377]	valid's auc: 0.983647
# [378]	valid's auc: 0.98365
# [379]	valid's auc: 0.983652
# [380]	valid's auc: 0.983651
# [381]	valid's auc: 0.98366
# [382]	valid's auc: 0.983661
# [383]	valid's auc: 0.983661
# [384]	valid's auc: 0.983662
# [385]	valid's auc: 0.983666
# [386]	valid's auc: 0.983671
# [387]	valid's auc: 0.983665
# [388]	valid's auc: 0.983669
# [389]	valid's auc: 0.98366
# [390]	valid's auc: 0.983663
# [391]	valid's auc: 0.983663
# [392]	valid's auc: 0.98367
# [393]	valid's auc: 0.983674
# [394]	valid's auc: 0.983674
# [395]	valid's auc: 0.983678
# [396]	valid's auc: 0.98368
# [397]	valid's auc: 0.983681
# [398]	valid's auc: 0.983683
# [399]	valid's auc: 0.983682
# [400]	valid's auc: 0.983679
# [401]	valid's auc: 0.98367
# [402]	valid's auc: 0.983672
# [403]	valid's auc: 0.983675
# [404]	valid's auc: 0.983678
# [405]	valid's auc: 0.983676
# [406]	valid's auc: 0.983677
# [407]	valid's auc: 0.983681
# [408]	valid's auc: 0.98369
# [409]	valid's auc: 0.983687
# [410]	valid's auc: 0.983689
# [411]	valid's auc: 0.983696
# [412]	valid's auc: 0.983692
# [413]	valid's auc: 0.983691
# [414]	valid's auc: 0.983685
# [415]	valid's auc: 0.983684
# [416]	valid's auc: 0.983685
# [417]	valid's auc: 0.983682
# [418]	valid's auc: 0.983685
# [419]	valid's auc: 0.983687
# [420]	valid's auc: 0.983686
# [421]	valid's auc: 0.983691
# [422]	valid's auc: 0.983693
# [423]	valid's auc: 0.983692
# [424]	valid's auc: 0.983696
# [425]	valid's auc: 0.983688
# [426]	valid's auc: 0.983687
# [427]	valid's auc: 0.983686
# [428]	valid's auc: 0.983702
# [429]	valid's auc: 0.983703
# [430]	valid's auc: 0.983704
# [431]	valid's auc: 0.983704
# [432]	valid's auc: 0.983703
# [433]	valid's auc: 0.983699
# [434]	valid's auc: 0.983702
# [435]	valid's auc: 0.983702
# [436]	valid's auc: 0.983701
# [437]	valid's auc: 0.983702
# [438]	valid's auc: 0.983706
# [439]	valid's auc: 0.983705
# [440]	valid's auc: 0.983703
# [441]	valid's auc: 0.983699
# [442]	valid's auc: 0.983698
# [443]	valid's auc: 0.983703
# [444]	valid's auc: 0.983704
# [445]	valid's auc: 0.983706
# [446]	valid's auc: 0.983713
# [447]	valid's auc: 0.983715
# [448]	valid's auc: 0.983709
# [449]	valid's auc: 0.983704
# [450]	valid's auc: 0.983704
# [451]	valid's auc: 0.983701
# [452]	valid's auc: 0.983696
# [453]	valid's auc: 0.983694
# [454]	valid's auc: 0.983695
# [455]	valid's auc: 0.983694
# [456]	valid's auc: 0.983694
# [457]	valid's auc: 0.983698
# [458]	valid's auc: 0.983698
# [459]	valid's auc: 0.983697
# [460]	valid's auc: 0.983695
# [461]	valid's auc: 0.983695
# [462]	valid's auc: 0.983698
# [463]	valid's auc: 0.983705
# [464]	valid's auc: 0.983706
# [465]	valid's auc: 0.983707
# [466]	valid's auc: 0.983704
# [467]	valid's auc: 0.983709
# [468]	valid's auc: 0.983709
# [469]	valid's auc: 0.983706
# [470]	valid's auc: 0.983709
# [471]	valid's auc: 0.983708
# [472]	valid's auc: 0.983705
# [473]	valid's auc: 0.983705
# [474]	valid's auc: 0.983705
# [475]	valid's auc: 0.983703
# [476]	valid's auc: 0.98371
# [477]	valid's auc: 0.983709
# [478]	valid's auc: 0.983707
# [479]	valid's auc: 0.983713
# [480]	valid's auc: 0.98371
# [481]	valid's auc: 0.983709
# [482]	valid's auc: 0.983708
# [483]	valid's auc: 0.983711
# [484]	valid's auc: 0.983721
# [485]	valid's auc: 0.983722
# [486]	valid's auc: 0.983717
# [487]	valid's auc: 0.983722
# [488]	valid's auc: 0.983726
# [489]	valid's auc: 0.983729
# [490]	valid's auc: 0.983728
# [491]	valid's auc: 0.98373
# [492]	valid's auc: 0.983734
# [493]	valid's auc: 0.983734
# [494]	valid's auc: 0.983736
# [495]	valid's auc: 0.983738
# [496]	valid's auc: 0.983741
# [497]	valid's auc: 0.983741
# [498]	valid's auc: 0.983741
# [499]	valid's auc: 0.983738
# [500]	valid's auc: 0.983736
# Did not meet early stopping. Best iteration is:
# [498]	valid's auc: 0.983741
# 131

# %%
n_estimators = booster.best_iteration
metrics = 'auc'

print('\nModel Info:')
print('n_estimators:', n_estimators)
print(metrics+':', evals_results['valid'][metrics][n_estimators-1])
# Out:
# Model Info:
# n_estimators: 250
# auc: 0.9835226130767334

# %%
n_estimators = booster.best_iteration
metrics = 'auc'

print('\nModel Info:')
print('n_estimators:', n_estimators)
print(metrics+':', evals_results['valid'][metrics][n_estimators-1])

# %%
ax = lgb.plot_importance(booster, max_num_features=100)
plt.show()

# %%
plt.savefig('0504-2imp.png', dpi=600, bbox_inches='tight')

# %%
gc.collect()
# Out:
# 156

# %%
with timer("load test data"):
    test_df = pd.read_csv(path+"test.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load test data] done in 14 s

# %%
test_df['click_time']= pd.to_datetime(test_df['click_time'])
testsup_df['click_time']= pd.to_datetime(testsup_df['click_time'])
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# preditions=booster.predict(test_df[predictors].values)

print("Predicting the submission data...")

testsup_df['is_attributed'] = booster.predict(testsup_df[predictors], num_iteration=booster.best_iteration)

print('projecting prediction onto test')

join_cols = ['ip', 'app', 'device', 'os', 'channel', 'click_time']
all_cols = join_cols + ['is_attributed']
# Out:
# Predicting the submission data...
# projecting prediction onto test
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
test_df = test_df.merge(testsup_df[all_cols], how='left', on=join_cols)

test_df = test_df.drop_duplicates(subset=['click_id'])

# %%
test_df.head()
# Out:
#    click_id      ip  app  device  os  channel          click_time  \
# 0         0    5744    9       1   3      107 2017-11-10 04:00:00
# 1         1  119901    9       1   3      466 2017-11-10 04:00:00
# 2         2   72287   21       1  19      128 2017-11-10 04:00:00
# 3         3   78477   15       1  13      111 2017-11-10 04:00:00
# 4         4  123080   12       1  13      328 2017-11-10 04:00:00
#
#    is_attributed
# 0       0.045579
# 1       0.013605
# 2       0.001977
# 3       0.028534
# 4       0.003971

# %%
test_df.count()
# Out:
# click_id         18790469
# ip               18790469
# app              18790469
# device           18790469
# os               18790469
# channel          18790469
# click_time       18790469
# is_attributed    18790469
# dtype: int64

# %%
print("Writing the submission data into a csv file...")

test_df[['click_id', 'is_attributed']].to_csv('0504-2.csv', index=False)

print("All done...")
# Out:
# Writing the submission data into a csv file...
# All done...
