# %% [markdown]
# train120m-180m, train:valid 90:10(shuffle)
# num_boost_round = 500, early_stopping_rounds = 50
# hyper parameter変更

# %%
import pandas as pd
import time
import numpy as np
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import gc
from contextlib import contextmanager
import matplotlib.pyplot as plt

# %%
@contextmanager
def timer(name):
    t0 = time.time()
    yield
    print(f'[{name}] done in {time.time() - t0:.0f} s')
    
def do_next_Click(df,agg_suffix='nextClick', agg_type='float32'):
    with timer("Adding next click times"):
    
        print(f">> \nExtracting {agg_suffix} time calculation features...\n")

        GROUP_BY_NEXT_CLICKS = [

        # V1
        # {'groupby': ['ip']},
        # {'groupby': ['ip', 'app']},
        # {'groupby': ['ip', 'channel']},
        # {'groupby': ['ip', 'os']},

        # V3
        {'groupby': ['ip', 'app', 'device', 'os', 'channel']},
        {'groupby': ['ip', 'os', 'device']},
        {'groupby': ['ip', 'os', 'device', 'app']},
    #     {'groupby': ['device']},
    #     {'groupby': ['device', 'channel']},     
        {'groupby': ['app', 'device', 'channel']},
#         {'groupby': ['device', 'hour']}
        ]

        # Calculate the time to next click for each group
        for spec in GROUP_BY_NEXT_CLICKS:

           # Name of new feature
            new_feature = '{}_{}'.format('_'.join(spec['groupby']),agg_suffix)    

            # Unique list of features to select
            all_features = spec['groupby'] + ['click_time']

            # Run calculation
            print(f">> Grouping by {spec['groupby']}, and saving time to {agg_suffix} in: {new_feature}")
            df[new_feature] = (df[all_features].groupby(spec[
                'groupby']).click_time.shift(-1) - df.click_time).dt.seconds.astype(agg_type)

#             predictors.append(new_feature)
            gc.collect()
        return (df)

def df_add_counts(df, cols):
    arr_slice = df[cols].values
    unq, unqtags, counts = np.unique(np.ravel_multi_index(arr_slice.T, arr_slice.max(axis=0) + 1),
                                     return_inverse=True, return_counts=True)
    df["_".join(cols)+'_count'] = counts[unqtags]
    gc.collect()
    
def make_count_features(df):
    with timer("add count features"):
        df['click_time']= pd.to_datetime(df['click_time'])
        dt= df['click_time'].dt
#         df['day'] = dt.day.astype('uint8')
        df['hour'] = dt.hour.astype('uint8')
#         df['minute'] = dt.minute.astype('uint8')
#         df['second'] = dt.second.astype('uint8')#secondを追加

        del(dt)
        
        df_add_counts(df, ['ip'])
#         df_add_counts(df, ['ip','day','hour','minute'])
        df_add_counts(df, ['os','device'])
        df_add_counts(df, ['os','app','channel'])
        
        df_add_counts(df, ['ip', 'hour'])
        df_add_counts(df, ['ip', 'app'])
        df_add_counts(df, ['ip', 'app', 'os'])
        df_add_counts(df, ['ip', 'device'])
        df_add_counts(df, ['app', 'channel'])

def do_countuniq( df, group_cols, counted, agg_type='uint32', show_max=False, show_agg=True ):
    agg_name= '{}_by_{}_countuniq'.format(('_'.join(group_cols)),(counted))  
    if show_agg:
        print( "\nCounting unqiue ", counted, " by ", group_cols ,  '... and saved in', agg_name )
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].nunique().reset_index().rename(columns={counted:agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    if show_max:
        print( agg_name + " max value = ", df[agg_name].max() )
    df[agg_name] = df[agg_name].astype(agg_type)
#     predictors.append(agg_name)
#     print('predictors',predictors)
    gc.collect()
    return( df )

def make_countuniq_features(df):
    with timer("add countuniq features"):
        df = do_countuniq( df, ['ip'], 'channel' ); gc.collect()
        df = do_countuniq( df, ['ip', 'device', 'os'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip'], 'hour' ); gc.collect()
        df = do_countuniq( df, ['ip'], 'app'); gc.collect()
        df = do_countuniq( df, ['ip', 'app'], 'os'); gc.collect()
        df = do_countuniq( df, ['ip'], 'device'); gc.collect()
        df = do_countuniq( df, ['app'], 'channel'); gc.collect()
        return(df)

# def make_next_click_feature(df):
#     with timer("Adding next click times"):
#         D= 2**26
#         df['category'] = (df['ip'].astype(str) + "_" + df['app'].astype(str) + "_" + df['device'].astype(str) \
#                          + "_" + df['os'].astype(str)).apply(hash) % D
#         click_buffer= np.full(D, 3000000000, dtype=np.uint32)
#         df['epochtime']= df['click_time'].astype(np.int64) // 10 ** 9
#         next_clicks= []
#         for category, time in zip(reversed(df['category'].values), reversed(df['epochtime'].values)):
#             next_clicks.append(click_buffer[category]-time)
#             click_buffer[category]= time
#         del(click_buffer)
#         df['next_click']= list(reversed(next_clicks))
#         gc.collect()
        
path = '~/talkingdata/input/'

dtypes = {
        'ip'            : 'uint32',
        'app'           : 'uint16',
        'device'        : 'uint16',
        'os'            : 'uint16',
        'channel'       : 'uint16',
        'is_attributed' : 'uint8',
        'click_id'      : 'uint32'
        }

columns = ['ip','app','device','os', 'channel', 'click_time', 'is_attributed']

# %%
with timer("load training data"):
    train_df = pd.read_csv(path+"train.csv",skiprows=range(1,122071518), usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)

with timer("load test data"):
    testsup_df = pd.read_csv(path+"test_supplement.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load training data] done in 120 s
# [load test data] done in 43 s

# %%
num_train = train_df.shape[0]

y = train_df.is_attributed.values
gc.collect()

# sub = pd.DataFrame()
# sub['click_id'] = test_df.click_id.values

common_column = ['ip','app','device','os','channel','click_time']
concat_df = pd.concat([train_df[common_column],testsup_df[common_column]])

del train_df, testsup_df
gc.collect()
# Out:
# 64

# %%
# from multiprocessing import Pool
# import multiprocessing as multi

# p = Pool(multi.cpu_count())
# p.map(make_count_features, concat_df)
# p.close()

# %%
make_count_features(concat_df)
# Out:
# [add count features] done in 456 s

# %%
concat_df = make_countuniq_features(concat_df)

gc.collect()
# Out:
# Counting unqiue  channel  by  ['ip'] ... and saved in ip_by_channel_countuniq
#
# Counting unqiue  app  by  ['ip', 'device', 'os'] ... and saved in ip_device_os_by_app_countuniq
#
# Counting unqiue  hour  by  ['ip'] ... and saved in ip_by_hour_countuniq
#
# Counting unqiue  app  by  ['ip'] ... and saved in ip_by_app_countuniq
#
# Counting unqiue  os  by  ['ip', 'app'] ... and saved in ip_app_by_os_countuniq
#
# Counting unqiue  device  by  ['ip'] ... and saved in ip_by_device_countuniq
#
# Counting unqiue  channel  by  ['app'] ... and saved in app_by_channel_countuniq
# [add countuniq features] done in 1032 s
# 41

# %%
concat_df = do_next_Click(concat_df)
gc.collect()
# Out:
# >>
# Extracting nextClick time calculation features...
#
# >> Grouping by ['ip', 'os', 'device', 'app'], and saving time to nextClick in: ip_os_device_app_nextClick
# >> Grouping by ['app', 'device', 'channel'], and saving time to nextClick in: app_device_channel_nextClick
# [Adding next click times] done in 1464 s
# 0

# %%
concat_df.head()
# Out:
#        ip  app  device   os  channel          click_time  hour  ip_count  \
# 0   62766    7    3543  748      101 2017-11-08 16:00:00    16      3103
# 1  108229   15       1   19      245 2017-11-08 16:00:00    16      7399
# 2   73487   12       2   22      326 2017-11-08 16:00:00    16    486915
# 3  238206   14       1   19      379 2017-11-08 16:00:00    16         1
# 4   27482   26       1   32      121 2017-11-08 16:00:00    16      3958
#
#    os_device_count  os_app_channel_count              ...               \
# 0                1                     1              ...
# 1         27561927                289727              ...
# 2           158918                 14319              ...
# 3         27561927                319932              ...
# 4          1006744                  9873              ...
#
#    ip_device_os_by_app_countuniq  ip_by_hour_countuniq  ip_by_app_countuniq  \
# 0                              1                    24                   43
# 1                             32                    24                   46
# 2                             28                    24                  173
# 3                              1                     1                    1
# 4                             17                    24                   47
#
#    ip_app_by_os_countuniq  ip_by_device_countuniq  app_by_channel_countuniq  \
# 0                      10                       7                         3
# 1                      44                      12                        27
# 2                     125                     148                        32
# 3                       1                       1                        38
# 4                      17                      12                         5
#
#    ip_app_device_os_channel_nextClick  ip_os_device_nextClick  \
# 0                                 NaN                     NaN
# 1                               371.0                    58.0
# 2                               181.0                    15.0
# 3                                 NaN                     NaN
# 4                             32379.0                    16.0
#
#    ip_os_device_app_nextClick  app_device_channel_nextClick
# 0                         NaN                           NaN
# 1                       200.0                           1.0
# 2                       181.0                           1.0
# 3                         NaN                           1.0
# 4                       927.0                           1.0
#
# [5 rows x 26 columns]

# %%
train_df = concat_df.iloc[:num_train]
testsup_df = concat_df.iloc[num_train:]

del concat_df
gc.collect()
# Out:
# 60

# %%
import sys

print("{}{: >25}{}{: >10}{}".format('|','Variable Name','|','Memory','|'))
print(" ------------------------------------ ")
for var_name in dir():
    if not var_name.startswith("_"):
        print("{}{: >25}{}{: >10}{}".format('|',var_name,'|',sys.getsizeof(eval(var_name)),'|'))
gc.collect()
# Out:
# |            Variable Name|    Memory|
#  ------------------------------------
# |                       In|       432|
# |                      Out|       648|
# |                 all_cols|       120|
# |                       ax|        56|
# |              categorical|       104|
# |                  columns|       120|
# |            common_column|       112|
# |           contextmanager|       136|
# |            df_add_counts|       136|
# |             do_countuniq|       136|
# |            do_next_Click|       136|
# |                   dtypes|       368|
# |    early_stopping_rounds|        28|
# |            evals_results|       240|
# |                     exit|        56|
# |                        f|       176|
# |                       gc|        80|
# |              get_ipython|        64|
# |                join_cols|       112|
# |                      lgb|        80|
# |               lgb_params|       648|
# |      make_count_features|       136|
# |  make_countuniq_features|       136|
# |                  metrics|        52|
# |             n_estimators|        28|
# |                       np|        80|
# |          num_boost_round|        28|
# |                num_train|        28|
# |                     path|        69|
# |                       pd|        80|
# |                   pickle|        80|
# |                      plt|        80|
# |               predictors|       328|
# |                     quit|        56|
# |                      sys|        80|
# |                   target|       118|
# |                  test_df| 751618784|
# |               testsup_df|8342938249|
# |                     time|        80|
# |                    timer|       136|
# |         train_test_split|       136|
# |                 var_name|        57|
# |                  xgtrain|        56|
# |                  xgvalid|        56|
# 267

# %%
import pickle
# with open('train_after.csv.pkl','wb') as f:
#   pickle.dump(train_df, f, protocol=4)

# with open('testsup_after.csv.pkl','wb') as f:
#   pickle.dump(testsup_df, f, protocol=4)

# with open('test_after.csv.pkl','wb') as f:
#   pickle.dump(test_df, f, protocol=2)

# %%
import pickle
# train_df = pd.DataFrame()
with open('train_after.csv.pkl','rb') as f:
  train_df = pickle.load(f)

with open('testsup_after.csv.pkl','rb') as f:
  testsup_df = pickle.load(f)

with open('y.csv.pkl','rb') as f:
  y = pickle.load(f)

# %%
# with timer("load training data"):
#     train = pd.read_csv(path+"train.csv",skiprows=range(1,122071518), usecols=['ip','app','device','os', 'channel', 'click_time', 'is_attributed'], dtype=dtypes)
# y = train.is_attributed.values
# del train
# Out:
# [load training data] done in 131 s

# %%
# with open('y.csv.pkl','wb') as f:
#   pickle.dump(y, f, protocol=4)

# %%
x_train, x_val, y_train, y_val = train_test_split(train_df, y, train_size=0.9, random_state=0)

del train_df, y
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
evals_results = {}
# num_boost_round = 250
# early_stopping_rounds = 30
num_boost_round = 1000
early_stopping_rounds = 50

# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'subsample_for_bin': 200000,  # Number of samples for constructing bin
#     'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
#     'reg_alpha': 0,  # L1 regularization term on weights
#     'reg_lambda': 0,  # L2 regularization term on weights
#     'nthread': 8,
#     'verbose': 0,
#     'metric':'auc',     
 
#     'learning_rate': 0.15,
#     'num_leaves': 7,  # 2^max_depth - 1
#     'max_depth': 3,  # -1 means no limit
#     'min_child_samples': 100,  # Minimum number of data need in a child(min_data_in_leaf)
#     'max_bin': 100,  # Number of bucketed bin for feature values
#     'subsample': 0.7,  # Subsample ratio of the training instance.
#     'subsample_freq': 1,  # frequence of subsample, <=0 means no enable
#     'colsample_bytree': 0.9,  # Subsample ratio of columns when constructing each tree.
#     'min_child_weight': 0,  # Minimum sum of instance weight(hessian) needed in a child(leaf)
#     'scale_pos_weight':99
# }

# matsuda Hyperparameters
min_data_in_leaf = 100
# min_data_in_leaf = 50
max_bin = 127
bagging_fraction = 0.7
bagging_freq = 1 
feature_fraction = 0.9
bin_construct_sample_cnt = 100000
min_hessian = 0 
scale_pos_weight = 200
max_depth = -1

lgb_params = {
   'boosting_type': 'gbdt',
   'objective': 'binary',
   'min_split_gain': 0,  # lambda_l1, lambda_l2 and min_gain_to_split to regularization
   'nthread': 8,
   'verbose': 0,
   'metric': 'auc',
   'learning_rate': 0.05,
#    'learning_rate': 0.1,
   'max_depth': max_depth,  # -1 means no limit
   'num_leaves': 31,  # 2^max_depth - 1
   'min_child_samples': min_data_in_leaf,  # Minimum number of data need in a child(min_data_in_leaf)
   'max_bin': max_bin,  # Number of bucketed bin for feature values
   'bin_construct_sample_cnt': bin_construct_sample_cnt,
   # 'subsample_for_bin': 20000,  # Number of samples for constructing bin
   'bagging_fraction': bagging_fraction,  # subsample
   'bagging_freq': bagging_freq,  # subsample_freq
   'feature_fraction': feature_fraction,  # colsample_bytree
   'min_sum_hessian_in_leaf': min_hessian,  # min_child_weight
   'scale_pos_weight': scale_pos_weight
}


# metrics = 'auc'
# lgb_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'binary',
#     'metric': metrics,
#     'learning_rate': .1,
#     'num_leaves': 7,
#     'max_depth': 4,
#     'min_child_samples': 100,
#     'max_bin': 100,
#     'subsample': 0.7,
#     'subsample_freq': 1,
#     'colsample_bytree': 0.7,
#     'min_child_weight': 0,
#     'min_split_gain': 0,
#     'nthread': 4,
#     'verbose': 1,
#     'scale_pos_weight': 99.7
#     #'scale_pos_weight': 400
# }

# %%
target = "is_attributed"
categorical = ['app','os','channel','device','hour']
predictors = list(set(x_train.columns)-set([target])-set(['click_time','ip']))
print(predictors)

print("preparing validation datasets")

xgtrain = lgb.Dataset(x_train[predictors].values,
                      label=y_train,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_train
del y_train
gc.collect()

xgvalid = lgb.Dataset(x_val[predictors].values,
                      label=y_val,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )

del x_val
del y_val
gc.collect()
# Out:
# ['ip_by_hour_countuniq', 'os_app_channel_count', 'device', 'os_device_count', 'hour', 'ip_app_by_os_countuniq', 'channel', 'app_channel_count', 'os', 'ip_device_os_by_app_countuniq', 'ip_os_device_nextClick', 'ip_os_device_app_nextClick', 'app_by_channel_countuniq', 'ip_app_device_os_channel_nextClick', 'ip_by_device_countuniq', 'ip_by_app_countuniq', 'ip_hour_count', 'ip_app_count', 'ip_app_os_count', 'ip_by_channel_countuniq', 'ip_count', 'app_device_channel_nextClick', 'app', 'ip_device_count']
# preparing validation datasets
# 34

# %%
# gc.collect()
# del booster
booster = lgb.train(
     lgb_params, 
     xgtrain,
     valid_sets=[xgvalid],
     valid_names=['valid'],
     evals_result=evals_results, 
     num_boost_round=num_boost_round,
     early_stopping_rounds=early_stopping_rounds,
     verbose_eval=1
)

del xgvalid
del xgtrain
gc.collect()
# Out:
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/um003580/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overrided.
#   warnings.warn('categorical_feature in param dict is overrided.')
# [1]	valid's auc: 0.96324
# Training until validation scores don't improve for 50 rounds.
# [2]	valid's auc: 0.970799
# [3]	valid's auc: 0.972691
# [4]	valid's auc: 0.972456
# [5]	valid's auc: 0.973015
# [6]	valid's auc: 0.974143
# [7]	valid's auc: 0.974452
# [8]	valid's auc: 0.974541
# [9]	valid's auc: 0.974569
# [10]	valid's auc: 0.974503
# [11]	valid's auc: 0.974707
# [12]	valid's auc: 0.975118
# [13]	valid's auc: 0.975253
# [14]	valid's auc: 0.975268
# [15]	valid's auc: 0.975474
# [16]	valid's auc: 0.975603
# [17]	valid's auc: 0.975605
# [18]	valid's auc: 0.976031
# [19]	valid's auc: 0.976147
# [20]	valid's auc: 0.976256
# [21]	valid's auc: 0.976346
# [22]	valid's auc: 0.976363
# [23]	valid's auc: 0.976456
# [24]	valid's auc: 0.976559
# [25]	valid's auc: 0.97665
# [26]	valid's auc: 0.976731
# [27]	valid's auc: 0.976804
# [28]	valid's auc: 0.976847
# [29]	valid's auc: 0.977011
# [30]	valid's auc: 0.977222
# [31]	valid's auc: 0.977392
# [32]	valid's auc: 0.977466
# [33]	valid's auc: 0.97759
# [34]	valid's auc: 0.977735
# [35]	valid's auc: 0.977816
# [36]	valid's auc: 0.977864
# [37]	valid's auc: 0.977968
# [38]	valid's auc: 0.978138
# [39]	valid's auc: 0.978241
# [40]	valid's auc: 0.978321
# [41]	valid's auc: 0.978387
# [42]	valid's auc: 0.978449
# [43]	valid's auc: 0.978536
# [44]	valid's auc: 0.978661
# [45]	valid's auc: 0.978705
# [46]	valid's auc: 0.978849
# [47]	valid's auc: 0.97895
# [48]	valid's auc: 0.979001
# [49]	valid's auc: 0.979055
# [50]	valid's auc: 0.979147
# [51]	valid's auc: 0.979288
# [52]	valid's auc: 0.979352
# [53]	valid's auc: 0.979427
# [54]	valid's auc: 0.97949
# [55]	valid's auc: 0.979574
# [56]	valid's auc: 0.979784
# [57]	valid's auc: 0.979835
# [58]	valid's auc: 0.979967
# [59]	valid's auc: 0.98004
# [60]	valid's auc: 0.980104
# [61]	valid's auc: 0.980183
# [62]	valid's auc: 0.980267
# [63]	valid's auc: 0.980359
# [64]	valid's auc: 0.980417
# [65]	valid's auc: 0.980455
# [66]	valid's auc: 0.980489
# [67]	valid's auc: 0.980573
# [68]	valid's auc: 0.980624
# [69]	valid's auc: 0.980699
# [70]	valid's auc: 0.98075
# [71]	valid's auc: 0.98082
# [72]	valid's auc: 0.98087
# [73]	valid's auc: 0.980934
# [74]	valid's auc: 0.981009
# [75]	valid's auc: 0.981067
# [76]	valid's auc: 0.981139
# [77]	valid's auc: 0.981182
# [78]	valid's auc: 0.981251
# [79]	valid's auc: 0.98131
# [80]	valid's auc: 0.981361
# [81]	valid's auc: 0.981409
# [82]	valid's auc: 0.981443
# [83]	valid's auc: 0.981482
# [84]	valid's auc: 0.981515
# [85]	valid's auc: 0.981554
# [86]	valid's auc: 0.981587
# [87]	valid's auc: 0.981643
# [88]	valid's auc: 0.981702
# [89]	valid's auc: 0.981735
# [90]	valid's auc: 0.981794
# [91]	valid's auc: 0.981835
# [92]	valid's auc: 0.981853
# [93]	valid's auc: 0.981905
# [94]	valid's auc: 0.981951
# [95]	valid's auc: 0.981987
# [96]	valid's auc: 0.982029
# [97]	valid's auc: 0.982069
# [98]	valid's auc: 0.98209
# [99]	valid's auc: 0.982139
# [100]	valid's auc: 0.982178
# [101]	valid's auc: 0.982198
# [102]	valid's auc: 0.982218
# [103]	valid's auc: 0.982273
# [104]	valid's auc: 0.982314
# [105]	valid's auc: 0.982371
# [106]	valid's auc: 0.982398
# [107]	valid's auc: 0.982435
# [108]	valid's auc: 0.982471
# [109]	valid's auc: 0.982508
# [110]	valid's auc: 0.982527
# [111]	valid's auc: 0.982566
# [112]	valid's auc: 0.982586
# [113]	valid's auc: 0.982603
# [114]	valid's auc: 0.982619
# [115]	valid's auc: 0.982646
# [116]	valid's auc: 0.982671
# [117]	valid's auc: 0.982695
# [118]	valid's auc: 0.98272
# [119]	valid's auc: 0.982749
# [120]	valid's auc: 0.982778
# [121]	valid's auc: 0.9828
# [122]	valid's auc: 0.982828
# [123]	valid's auc: 0.982843
# [124]	valid's auc: 0.982857
# [125]	valid's auc: 0.982878
# [126]	valid's auc: 0.982901
# [127]	valid's auc: 0.982926
# [128]	valid's auc: 0.982944
# [129]	valid's auc: 0.982962
# [130]	valid's auc: 0.982987
# [131]	valid's auc: 0.982988
# [132]	valid's auc: 0.983004
# [133]	valid's auc: 0.983021
# [134]	valid's auc: 0.983041
# [135]	valid's auc: 0.98304
# [136]	valid's auc: 0.983057
# [137]	valid's auc: 0.983081
# [138]	valid's auc: 0.983102
# [139]	valid's auc: 0.983123
# [140]	valid's auc: 0.983132
# [141]	valid's auc: 0.983144
# [142]	valid's auc: 0.983152
# [143]	valid's auc: 0.983159
# [144]	valid's auc: 0.983174
# [145]	valid's auc: 0.983184
# [146]	valid's auc: 0.983189
# [147]	valid's auc: 0.983204
# [148]	valid's auc: 0.983216
# [149]	valid's auc: 0.983226
# [150]	valid's auc: 0.983226
# [151]	valid's auc: 0.983243
# [152]	valid's auc: 0.983249
# [153]	valid's auc: 0.983259
# [154]	valid's auc: 0.983262
# [155]	valid's auc: 0.983269
# [156]	valid's auc: 0.983283
# [157]	valid's auc: 0.983309
# [158]	valid's auc: 0.98332
# [159]	valid's auc: 0.983322
# [160]	valid's auc: 0.983331
# [161]	valid's auc: 0.983338
# [162]	valid's auc: 0.983345
# [163]	valid's auc: 0.983357
# [164]	valid's auc: 0.983357
# [165]	valid's auc: 0.983369
# [166]	valid's auc: 0.983387
# [167]	valid's auc: 0.983395
# [168]	valid's auc: 0.983399
# [169]	valid's auc: 0.983398
# [170]	valid's auc: 0.983409
# [171]	valid's auc: 0.983416
# [172]	valid's auc: 0.983417
# [173]	valid's auc: 0.983424
# [174]	valid's auc: 0.983437
# [175]	valid's auc: 0.983451
# [176]	valid's auc: 0.983458
# [177]	valid's auc: 0.983467
# [178]	valid's auc: 0.983473
# [179]	valid's auc: 0.983474
# [180]	valid's auc: 0.983486
# [181]	valid's auc: 0.983488
# [182]	valid's auc: 0.983493
# [183]	valid's auc: 0.983501
# [184]	valid's auc: 0.983505
# [185]	valid's auc: 0.983509
# [186]	valid's auc: 0.983513
# [187]	valid's auc: 0.983514
# [188]	valid's auc: 0.983527
# [189]	valid's auc: 0.98353
# [190]	valid's auc: 0.983552
# [191]	valid's auc: 0.983557
# [192]	valid's auc: 0.983567
# [193]	valid's auc: 0.983571
# [194]	valid's auc: 0.983574
# [195]	valid's auc: 0.983581
# [196]	valid's auc: 0.983581
# [197]	valid's auc: 0.983581
# [198]	valid's auc: 0.983577
# [199]	valid's auc: 0.983581
# [200]	valid's auc: 0.983585
# [201]	valid's auc: 0.983596
# [202]	valid's auc: 0.983596
# [203]	valid's auc: 0.983602
# [204]	valid's auc: 0.983612
# [205]	valid's auc: 0.983623
# [206]	valid's auc: 0.983629
# [207]	valid's auc: 0.983639
# [208]	valid's auc: 0.98364
# [209]	valid's auc: 0.983642
# [210]	valid's auc: 0.983648
# [211]	valid's auc: 0.983647
# [212]	valid's auc: 0.983655
# [213]	valid's auc: 0.983671
# [214]	valid's auc: 0.983668
# [215]	valid's auc: 0.983672
# [216]	valid's auc: 0.983681
# [217]	valid's auc: 0.983689
# [218]	valid's auc: 0.983698
# [219]	valid's auc: 0.983704
# [220]	valid's auc: 0.983707
# [221]	valid's auc: 0.983707
# [222]	valid's auc: 0.983708
# [223]	valid's auc: 0.983712
# [224]	valid's auc: 0.983721
# [225]	valid's auc: 0.983725
# [226]	valid's auc: 0.983726
# [227]	valid's auc: 0.983722
# [228]	valid's auc: 0.983724
# [229]	valid's auc: 0.983725
# [230]	valid's auc: 0.983732
# [231]	valid's auc: 0.983739
# [232]	valid's auc: 0.98374
# [233]	valid's auc: 0.983742
# [234]	valid's auc: 0.983745
# [235]	valid's auc: 0.983743
# [236]	valid's auc: 0.983745
# [237]	valid's auc: 0.983749
# [238]	valid's auc: 0.983748
# [239]	valid's auc: 0.983746
# [240]	valid's auc: 0.983745
# [241]	valid's auc: 0.983754
# [242]	valid's auc: 0.983758
# [243]	valid's auc: 0.983758
# [244]	valid's auc: 0.983763
# [245]	valid's auc: 0.983767
# [246]	valid's auc: 0.983766
# [247]	valid's auc: 0.983762
# [248]	valid's auc: 0.98376
# [249]	valid's auc: 0.983758
# [250]	valid's auc: 0.983762
# [251]	valid's auc: 0.983771
# [252]	valid's auc: 0.983767
# [253]	valid's auc: 0.983771
# [254]	valid's auc: 0.983772
# [255]	valid's auc: 0.983773
# [256]	valid's auc: 0.983775
# [257]	valid's auc: 0.983776
# [258]	valid's auc: 0.983779
# [259]	valid's auc: 0.983785
# [260]	valid's auc: 0.98379
# [261]	valid's auc: 0.983797
# [262]	valid's auc: 0.983796
# [263]	valid's auc: 0.983801
# [264]	valid's auc: 0.983804
# [265]	valid's auc: 0.983806
# [266]	valid's auc: 0.98381
# [267]	valid's auc: 0.983814
# [268]	valid's auc: 0.983817
# [269]	valid's auc: 0.983817
# [270]	valid's auc: 0.983821
# [271]	valid's auc: 0.983824
# [272]	valid's auc: 0.983828
# [273]	valid's auc: 0.983835
# [274]	valid's auc: 0.983835
# [275]	valid's auc: 0.98384
# [276]	valid's auc: 0.983843
# [277]	valid's auc: 0.983847
# [278]	valid's auc: 0.983848
# [279]	valid's auc: 0.983845
# [280]	valid's auc: 0.983847
# [281]	valid's auc: 0.983853
# [282]	valid's auc: 0.983851
# [283]	valid's auc: 0.983849
# [284]	valid's auc: 0.983847
# [285]	valid's auc: 0.983843
# [286]	valid's auc: 0.983843
# [287]	valid's auc: 0.983848
# [288]	valid's auc: 0.983849
# [289]	valid's auc: 0.983852
# [290]	valid's auc: 0.983852
# [291]	valid's auc: 0.983854
# [292]	valid's auc: 0.983851
# [293]	valid's auc: 0.983852
# [294]	valid's auc: 0.983855
# [295]	valid's auc: 0.98386
# [296]	valid's auc: 0.983866
# [297]	valid's auc: 0.983869
# [298]	valid's auc: 0.983873
# [299]	valid's auc: 0.983876
# [300]	valid's auc: 0.983878
# [301]	valid's auc: 0.983883
# [302]	valid's auc: 0.983884
# [303]	valid's auc: 0.983886
# [304]	valid's auc: 0.983888
# [305]	valid's auc: 0.983893
# [306]	valid's auc: 0.983888
# [307]	valid's auc: 0.98389
# [308]	valid's auc: 0.983888
# [309]	valid's auc: 0.98389
# [310]	valid's auc: 0.983891
# [311]	valid's auc: 0.98389
# [312]	valid's auc: 0.983891
# [313]	valid's auc: 0.98389
# [314]	valid's auc: 0.983891
# [315]	valid's auc: 0.983899
# [316]	valid's auc: 0.983899
# [317]	valid's auc: 0.983903
# [318]	valid's auc: 0.983901
# [319]	valid's auc: 0.983908
# [320]	valid's auc: 0.983912
# [321]	valid's auc: 0.983913
# [322]	valid's auc: 0.983913
# [323]	valid's auc: 0.98391
# [324]	valid's auc: 0.983908
# [325]	valid's auc: 0.98391
# [326]	valid's auc: 0.983912
# [327]	valid's auc: 0.983914
# [328]	valid's auc: 0.983911
# [329]	valid's auc: 0.983912
# [330]	valid's auc: 0.983914
# [331]	valid's auc: 0.983912
# [332]	valid's auc: 0.983916
# [333]	valid's auc: 0.98392
# [334]	valid's auc: 0.983927
# [335]	valid's auc: 0.983924
# [336]	valid's auc: 0.983923
# [337]	valid's auc: 0.98392
# [338]	valid's auc: 0.983922
# [339]	valid's auc: 0.983924
# [340]	valid's auc: 0.983925
# [341]	valid's auc: 0.983924
# [342]	valid's auc: 0.983921
# [343]	valid's auc: 0.983928
# [344]	valid's auc: 0.983924
# [345]	valid's auc: 0.983921
# [346]	valid's auc: 0.983927
# [347]	valid's auc: 0.983927
# [348]	valid's auc: 0.983923
# [349]	valid's auc: 0.983922
# [350]	valid's auc: 0.983923
# [351]	valid's auc: 0.983919
# [352]	valid's auc: 0.983917
# [353]	valid's auc: 0.983914
# [354]	valid's auc: 0.983923
# [355]	valid's auc: 0.98392
# [356]	valid's auc: 0.983921
# [357]	valid's auc: 0.98393
# [358]	valid's auc: 0.983932
# [359]	valid's auc: 0.983932
# [360]	valid's auc: 0.983929
# [361]	valid's auc: 0.983927
# [362]	valid's auc: 0.983926
# [363]	valid's auc: 0.983926
# [364]	valid's auc: 0.983924
# [365]	valid's auc: 0.983923
# [366]	valid's auc: 0.983928
# [367]	valid's auc: 0.983931
# [368]	valid's auc: 0.983926
# [369]	valid's auc: 0.983923
# [370]	valid's auc: 0.983921
# [371]	valid's auc: 0.983922
# [372]	valid's auc: 0.983923
# [373]	valid's auc: 0.983926
# [374]	valid's auc: 0.983927
# [375]	valid's auc: 0.983926
# [376]	valid's auc: 0.983926
# [377]	valid's auc: 0.983926
# [378]	valid's auc: 0.983925
# [379]	valid's auc: 0.983925
# [380]	valid's auc: 0.983923
# [381]	valid's auc: 0.983924
# [382]	valid's auc: 0.983927
# [383]	valid's auc: 0.983926
# [384]	valid's auc: 0.983923
# [385]	valid's auc: 0.98392
# [386]	valid's auc: 0.983924
# [387]	valid's auc: 0.983927
# [388]	valid's auc: 0.983925
# [389]	valid's auc: 0.983925
# [390]	valid's auc: 0.983926
# [391]	valid's auc: 0.983931
# [392]	valid's auc: 0.983933
# [393]	valid's auc: 0.983937
# [394]	valid's auc: 0.983938
# [395]	valid's auc: 0.983944
# [396]	valid's auc: 0.983941
# [397]	valid's auc: 0.983942
# [398]	valid's auc: 0.983941
# [399]	valid's auc: 0.983943
# [400]	valid's auc: 0.983942
# [401]	valid's auc: 0.983944
# [402]	valid's auc: 0.983942
# [403]	valid's auc: 0.98394
# [404]	valid's auc: 0.983941
# [405]	valid's auc: 0.983941
# [406]	valid's auc: 0.983943
# [407]	valid's auc: 0.983943
# [408]	valid's auc: 0.983947
# [409]	valid's auc: 0.983953
# [410]	valid's auc: 0.983953
# [411]	valid's auc: 0.983956
# [412]	valid's auc: 0.983955
# [413]	valid's auc: 0.983955
# [414]	valid's auc: 0.983954
# [415]	valid's auc: 0.983949
# [416]	valid's auc: 0.983949
# [417]	valid's auc: 0.983944
# [418]	valid's auc: 0.983942
# [419]	valid's auc: 0.983941
# [420]	valid's auc: 0.983939
# [421]	valid's auc: 0.98394
# [422]	valid's auc: 0.983941
# [423]	valid's auc: 0.983947
# [424]	valid's auc: 0.983945
# [425]	valid's auc: 0.983946
# [426]	valid's auc: 0.983948
# [427]	valid's auc: 0.983948
# [428]	valid's auc: 0.98395
# [429]	valid's auc: 0.983954
# [430]	valid's auc: 0.983953
# [431]	valid's auc: 0.983951
# [432]	valid's auc: 0.983954
# [433]	valid's auc: 0.983955
# [434]	valid's auc: 0.983953
# [435]	valid's auc: 0.983959
# [436]	valid's auc: 0.983959
# [437]	valid's auc: 0.983956
# [438]	valid's auc: 0.983958
# [439]	valid's auc: 0.983958
# [440]	valid's auc: 0.983963
# [441]	valid's auc: 0.983965
# [442]	valid's auc: 0.983963
# [443]	valid's auc: 0.983963
# [444]	valid's auc: 0.983959
# [445]	valid's auc: 0.983956
# [446]	valid's auc: 0.983954
# [447]	valid's auc: 0.983959
# [448]	valid's auc: 0.98396
# [449]	valid's auc: 0.98396
# [450]	valid's auc: 0.983957
# [451]	valid's auc: 0.983953
# [452]	valid's auc: 0.983953
# [453]	valid's auc: 0.983957
# [454]	valid's auc: 0.983955
# [455]	valid's auc: 0.983954
# [456]	valid's auc: 0.983955
# [457]	valid's auc: 0.983954
# [458]	valid's auc: 0.983955
# [459]	valid's auc: 0.983956
# [460]	valid's auc: 0.98396
# [461]	valid's auc: 0.983961
# [462]	valid's auc: 0.983961
# [463]	valid's auc: 0.983962
# [464]	valid's auc: 0.98396
# [465]	valid's auc: 0.983959
# [466]	valid's auc: 0.98396
# [467]	valid's auc: 0.983959
# [468]	valid's auc: 0.983957
# [469]	valid's auc: 0.983956
# [470]	valid's auc: 0.983956
# [471]	valid's auc: 0.983956
# [472]	valid's auc: 0.983954
# [473]	valid's auc: 0.983957
# [474]	valid's auc: 0.983957
# [475]	valid's auc: 0.98396
# [476]	valid's auc: 0.983959
# [477]	valid's auc: 0.98396
# [478]	valid's auc: 0.983964
# [479]	valid's auc: 0.983964
# [480]	valid's auc: 0.983964
# [481]	valid's auc: 0.983962
# [482]	valid's auc: 0.983962
# [483]	valid's auc: 0.983958
# [484]	valid's auc: 0.983957
# [485]	valid's auc: 0.983959
# [486]	valid's auc: 0.98396
# [487]	valid's auc: 0.983961
# [488]	valid's auc: 0.98396
# [489]	valid's auc: 0.98396
# [490]	valid's auc: 0.98396
# [491]	valid's auc: 0.983962
# Early stopping, best iteration is:
# [441]	valid's auc: 0.983965
# 41

# %%
n_estimators = booster.best_iteration
metrics = 'auc'

print('\nModel Info:')
print('n_estimators:', n_estimators)
print(metrics+':', evals_results['valid'][metrics][n_estimators-1])
# Out:
# Model Info:
# n_estimators: 441
# auc: 0.9839647744830552

# %%
ax = lgb.plot_importance(booster, max_num_features=100)
plt.show()

# %%
plt.savefig('0505-1imp.png', dpi=600, bbox_inches='tight')

# %%
gc.collect()
# Out:
# 156

# %%
with timer("load test data"):
    test_df = pd.read_csv(path+"test.csv", dtype=dtypes, usecols=['ip','app','device','os', 'channel', 'click_time', 'click_id'])
# Out:
# [load test data] done in 16 s

# %%
test_df['click_time']= pd.to_datetime(test_df['click_time'])
testsup_df['click_time']= pd.to_datetime(testsup_df['click_time'])

# %%
# preditions=booster.predict(test_df[predictors].values)

print("Predicting the submission data...")

testsup_df['is_attributed'] = booster.predict(testsup_df[predictors], num_iteration=booster.best_iteration)

print('projecting prediction onto test')

join_cols = ['ip', 'app', 'device', 'os', 'channel', 'click_time']
all_cols = join_cols + ['is_attributed']
# Out:
# Predicting the submission data...
# projecting prediction onto test

# %%
test_df = test_df.merge(testsup_df[all_cols], how='left', on=join_cols)

test_df = test_df.drop_duplicates(subset=['click_id'])

# %%
test_df.head()
# Out:
#    click_id      ip  app  device  os  channel          click_time  \
# 0         0    5744    9       1   3      107 2017-11-10 04:00:00
# 1         1  119901    9       1   3      466 2017-11-10 04:00:00
# 2         2   72287   21       1  19      128 2017-11-10 04:00:00
# 3         3   78477   15       1  13      111 2017-11-10 04:00:00
# 4         4  123080   12       1  13      328 2017-11-10 04:00:00
#
#    is_attributed
# 0       0.119633
# 1       0.013048
# 2       0.002381
# 3       0.051763
# 4       0.006064

# %%
test_df.count()
# Out:
# click_id         18790469
# ip               18790469
# app              18790469
# device           18790469
# os               18790469
# channel          18790469
# click_time       18790469
# is_attributed    18790469
# dtype: int64

# %%
print("Writing the submission data into a csv file...")

test_df[['click_id', 'is_attributed']].to_csv('0505-1.csv', index=False)

print("All done...")
# Out:
# Writing the submission data into a csv file...
# All done...
